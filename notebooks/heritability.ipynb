# %%
import os
import numpy as np
from tqdm import tqdm as tqdm
import pandas as pd
import bz2
import subprocess
import pickle as pkl
from itertools import chain
from glob import glob
from collections import defaultdict
from IPython.display import HTML

# %%
working_path = '/cluster/raid/home/f80878961/beestrong/'
count_path = '{}data/allele_freqs/sync_files/'.format(working_path)
tlf_path = '{}tlf/'.format(working_path)
script_path = "/cluster/raid/home/f80878961/scripts/tmp_scripts/"

# %%
# bs_ids = pheno_df['Colony'].to_list()
# snp_nr = 7023976 # will need sanity check here

# %% [markdown]
# ## Settings

# %%
snp_nr = 7023976 # wc -l BS17_0071.count -1

prefix = 'All'
if prefix == 'All':
    pheno_df = pd.read_table('/cluster/raid/home/f80878961/beestrong/data/metadata/whole_beestrong_data.csv').rename(
        columns={
            'num_bs':'Colony',
            'group':'Genetic group'
        })
else: 
    pheno_df = pd.read_csv('{}BeeStrong_metadata.csv'.format(tlf_path))

filtered_count_path = '{}data/allele_freqs/{}/'.format(working_path, prefix)
queen_geno_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)

bs_ids = sorted([x.split('/')[-1].split('.')[0] for x in glob('{}*.count.bz2'.format(count_path))])

chunk_size = 101 # 15 chunks
batch_file = '{}bsid_batch.txt'.format(filtered_count_path)

# bs_ids = pheno_df['Colony'].to_list()
print(len(set(bs_ids).intersection(pheno_df['Colony'].to_list())))
print(len(bs_ids))
assert pheno_df['Colony'].to_list() == bs_ids

# for SNP filtering
min_prev = 0.1 # prevalence threshold for common alleles (if >2 common allele, then real tri-allelic)
min_depth = 10 # both mean and median depth 
max_depth = 50
# Out:
# 1513
# 1513

# %% [markdown]
# ## Merge allele frequencies .sync files

# %% [markdown]
# ### Write per-allele count matrices (SNP x colony for A, T, C, G)

# %%
def write_merge_sync_script(script_fn, array_str):
    runstr="""#!/bin/bash -l
#SBATCH --array=ARRAY_STRING
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --mem=20g
#SBATCH --time=4:00:00
#SBATCH --job-name=merge_sync
#SBATCH --output=%x_%A_%a.out
#SBATCH --error=%x_%A_%a.err

modulesld
ebld
module use /software/anaconda3/envs/eb/easybuild/modules/all
conda activate planb

# file listing batches of BeeStrong ids (bs_id) for parallel computing
batch_file=$1
snp_nr=$2
count_path=$3
out_path=$4

batch_id=$SLURM_ARRAY_TASK_ID

# getting bs_ids
bs_ids=$(sed -n ${batch_id}'{p;q}' ${batch_file})

python ~/scripts/plan-b-omics/bin/merge_sync.py --batch_id ${batch_id} --snp_nr ${snp_nr} --bs_ids ${bs_ids} --count_path ${count_path} --out_path ${out_path}

echo DONE""".replace("ARRAY_STRING", array_str)
    with open(script_fn, 'w') as outf:
        outf.write(runstr)

# %%
# create batch file for first time
with open(batch_file, "w") as outf:
    for i in range(0, len(bs_ids), chunk_size):
        chunk = bs_ids[i:i+chunk_size]
        outf.write(",".join(chunk) + "\n")

# %%
array_str = '1-15'
script_fn = '{}merge_sync.run'.format(script_path)
write_merge_sync_script(script_fn, array_str)

# %%
# %%bash -s "$script_fn" "$batch_file" "$snp_nr" "$count_path" "$filtered_count_path"
# cd $5
# sbatch $1 $2 $3 $4 $5
# Out:
# Submitted batch job 1388883

# %% [markdown]
# ### Merge into 3-D matrix

# %%
with open(batch_file, "r") as inf:
    batch_bs_ids = [x.rstrip().split(',') for x in inf.readlines()]
assert sum([x == bs_ids[i] for i, x in enumerate(list(chain(*batch_bs_ids)))]) == len(bs_ids)

# %%
# %%time
allele2jj = {'A': 0, 'T': 1, 'C':2, 'G':3}
count_mat = np.zeros((snp_nr, len(bs_ids), len(allele2jj)), dtype=np.uint16)

for allele, jj in allele2jj.items():
    print(allele, jj)
    
    for j, b_bs_ids in enumerate(batch_bs_ids):
        batch_id = j + 1
        batch_size = len(b_bs_ids)
        with open('{}count_{}_{}.txt'.format(filtered_count_path, allele, batch_id), 'r') as inf:
            i = 0
            for l in tqdm(inf):                    
                count_mat[i, j * chunk_size : j * chunk_size + batch_size, jj] = np.array(l.split()[2:], dtype=np.int16)
                i += 1
# Out:
# A 0
# 7023976it [01:27, 79911.85it/s]
# 7023976it [01:12, 96871.43it/s]
# 7023976it [01:13, 95607.20it/s]
# 7023976it [01:12, 96395.80it/s]
# 7023976it [01:13, 95634.25it/s]
# 7023976it [01:13, 95841.95it/s]
# 7023976it [01:12, 96750.18it/s]
# 7023976it [01:13, 96216.97it/s]
# 7023976it [01:13, 96170.55it/s]
# 7023976it [01:13, 94955.64it/s]
# 7023976it [01:10, 99338.00it/s]
# 7023976it [01:10, 100071.38it/s]
# 7023976it [01:10, 99098.12it/s]
# 7023976it [01:20, 86892.53it/s]
# 7023976it [01:19, 88464.59it/s]
# T 1
# 7023976it [01:20, 87638.04it/s]
# 7023976it [01:19, 88887.25it/s]
# 7023976it [01:20, 87229.69it/s]
# 7023976it [01:21, 86617.28it/s]
# 7023976it [01:21, 86346.12it/s]
# 7023976it [01:20, 87418.80it/s]
# 7023976it [01:20, 87219.67it/s]
# 7023976it [01:22, 85541.27it/s]
# 7023976it [01:22, 85528.61it/s]
# 7023976it [01:22, 85412.89it/s]
# 7023976it [01:21, 86602.88it/s]
# 7023976it [01:21, 86004.87it/s]
# 7023976it [01:20, 86980.82it/s]
# 7023976it [01:21, 86634.61it/s]
# 7023976it [01:19, 87840.42it/s]
# C 2
# 7023976it [01:22, 85362.98it/s]
# 7023976it [01:21, 86695.99it/s]
# 7023976it [01:21, 86272.75it/s]
# 7023976it [01:21, 85767.50it/s]
# 7023976it [01:23, 83933.48it/s]
# 7023976it [01:21, 85708.65it/s]
# 7023976it [01:22, 85253.64it/s]
# 7023976it [01:22, 84884.01it/s]
# 7023976it [01:23, 84503.23it/s]
# 7023976it [01:23, 84575.33it/s]
# 7023976it [01:23, 84403.22it/s]
# 7023976it [01:22, 85003.84it/s]
# 7023976it [01:22, 84759.25it/s]
# 7023976it [01:23, 84321.06it/s]
# 7023976it [01:21, 86137.15it/s]
# G 3
# 7023976it [01:21, 86597.14it/s]
# 7023976it [01:21, 86523.52it/s]
# 7023976it [01:23, 84421.79it/s]
# 7023976it [01:21, 85817.88it/s]
# 7023976it [01:22, 85413.62it/s]
# 7023976it [01:22, 85604.58it/s]
# 7023976it [01:22, 85174.04it/s]
# 7023976it [01:23, 84585.02it/s]
# 7023976it [01:24, 83101.66it/s]
# 7023976it [01:22, 84669.79it/s]
# 7023976it [01:22, 84762.85it/s]
# 7023976it [01:22, 85111.30it/s]
# 7023976it [01:21, 86124.85it/s]
# 7023976it [01:22, 85098.11it/s]
# 7023976it [01:20, 86877.37it/s]
# CPU times: user 1h 9min 1s, sys: 10min 24s, total: 1h 19min 25s
# Wall time: 1h 20min 4s

# %%
# %%time
with open('{}count_mat.pkl'.format(filtered_count_path), 'wb') as outf:
    pkl.dump(count_mat, outf, protocol=pkl.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 909 ms, sys: 2min 15s, total: 2min 16s
# Wall time: 2min 33s

# %% [markdown]
# ## Filter SNPs and recode alleles

# %% [markdown]
# filtering
# 1. monoallelic filtering : 3/4 tables empty
# 2. mitochondrial SNP: contig NC_001566.1
# 3. tri-allelic SNP filtering: >2 allele present in min. 10% colonies, else delete variants from third and fourth alleles
# 4. min-max depth (10/50, on mean AND median) (after tri-allelic variants deletions, also not including N and deletions)

# %%
# %%time
with open('{}count_mat.pkl'.format(filtered_count_path), 'rb') as inf:
    count_mat = pkl.load(inf)
print(count_mat.nbytes/1000000000)
# Out:
# 85.018205504
# CPU times: user 0 ns, sys: 1min 10s, total: 1min 10s
# Wall time: 1min 26s

# %%
with open(batch_file, "r") as inf:
    batch_bs_ids = [x.rstrip().split(',') for x in inf.readlines()]
assert sum([x == bs_ids[i] for i, x in enumerate(list(chain(*batch_bs_ids)))]) == len(bs_ids)

# %%
batch_i = 0
batch_ii = len(bs_ids)
print(batch_ii)
# Out:
# 1513

# %%
# %%time
# counts the number of A, T, C, G allele per SNP # should take 7min
allele_prev = np.sum(count_mat[:, batch_i:batch_ii, :] > 0, axis=1)
allele_prev
# Out:
# CPU times: user 2min 44s, sys: 5.78 s, total: 2min 50s
# Wall time: 2min 51s
# array([[   1, 1513,    3,    9],
#        [   4, 1513,   27,    2],
#        [1513,   11,    2,   22],
#        ...,
#        [1437,  849,  118,  337],
#        [ 397, 1364, 1058,  218],
#        [ 335, 1504,  310,  170]])

# %%
# %%time
# if count 3/4 alleles == 0, then monoallelic
mono_mask = np.sum(allele_prev > 0, axis=1) == 1
print(np.sum(mono_mask))

# tri-allelic stringent
tri_stringent_mask = np.sum(allele_prev > 0, axis=1) > 2
print(np.sum(tri_stringent_mask))

# tri-allelic relaxed (filter SNP only when >2 common alleles, i.e., an allele present in >= 10% of colonies)
tri_mask = np.sum(allele_prev >= ((batch_ii - batch_i) * min_prev), axis=1) > 2
print(np.sum(tri_mask))
# Out:
# 3261
# 6963287
# 17207
# CPU times: user 433 ms, sys: 41.7 ms, total: 475 ms
# Wall time: 479 ms

# %%
# iterate through stringent tri-allelic SNPs: filter if ambigous else recode (delete 3rd and fourth)
ambi_mask = np.full(snp_nr, False)
for i in tqdm(np.argwhere(tri_stringent_mask).flatten()):

    # get number of alleles and sort by prevalence 
    atcg_prev = allele_prev[i, :]
    alleles_sorted_by_prevalence = np.argsort(atcg_prev)

    # if 2nd and 3rd alleles are equally common --> ambiguous --> filter
    if atcg_prev[alleles_sorted_by_prevalence[1]] == atcg_prev[alleles_sorted_by_prevalence[2]]:
        ambi_mask[i] = True

    # else delete 3rd and 4rth alleles
    else:
        count_mat[i, batch_i:batch_ii, alleles_sorted_by_prevalence[:2]] = 0

np.sum(ambi_mask)
# Out:
# 100%|██████████| 6963287/6963287 [00:50<00:00, 138304.88it/s]
# 122115

# %%
# %%time
# depth filtering --> if to, long I could consider iterating ...to have an overview of the time it takes # 8 min
depth  = np.sum(count_mat[:, batch_i:batch_ii, :], axis = 2)
# Out:
# CPU times: user 2min 23s, sys: 58 s, total: 3min 21s
# Wall time: 3min 22s

# %%
# %%time
mean_depth = np.mean(depth, axis = 1)
median_depth = np.full(snp_nr, -1) # np.median breaks the kernel somehow
for i in tqdm(range(snp_nr)):
    median_depth[i] =  np.median(depth[i])

depth_mask = (mean_depth < min_depth) | (mean_depth > max_depth) | (median_depth < min_depth) | (median_depth > max_depth) 
np.sum(depth_mask)
# Out:
# 100%|██████████| 7023976/7023976 [02:47<00:00, 41860.60it/s]
# CPU times: user 3min 4s, sys: 686 ms, total: 3min 5s
# Wall time: 3min 7s
# 123823

# %%
# %%time
chr_ids = [''] * snp_nr
snp_pos = [''] * snp_nr
mito_mask = np.full(snp_nr, False)
with open('{}count_A_1.txt'.format(filtered_count_path), 'r') as inf:
    i = 0
    for l in tqdm(inf):
        ch = l.split()[0]
        pos = l.split()[1]
        chr_ids[i] = ch
        snp_pos[i] = pos
        if ch == 'NC_001566.1':
            mito_mask[i] = True
        i += 1
np.sum(mito_mask)
# Out:
# 7023976it [00:25, 272771.65it/s]
# CPU times: user 23.4 s, sys: 2.03 s, total: 25.4 s
# Wall time: 25.8 s
# 287

# %%
# combine masks
mask = mono_mask + tri_mask + depth_mask + mito_mask + ambi_mask
print(np.sum(mask))
print(snp_nr - np.sum(mask))
# Out:
# 257718
# 6766258

# %% [markdown]
# ### Write PLINK bim_like files

# %% [markdown]
# 1. Chromosome code
# 2. Variant ID
# 3. Position in centimorgans (safe to use dummy value of '0')
# 4. Base-pair coordinate (1-based; limited to 231-2)
# 5. ALT ('A1' in PLINK 1.x) allele code
# 6. REF ('A2' in PLINK 1.x) allele code

# %%
# find reference and alternative allele per SNP (REF: the one with the most counts)
jj2allele = np.array(['A', 'T', 'C', 'G'])
ref_alt = np.full((snp_nr, 2), '.')
for i in tqdm(np.argwhere(~mask).flatten()):
    ref_alt[i] = jj2allele[np.argsort(np.sum(count_mat[i, :, :], axis=0))[::-1][:2]]
# Out:
# 100%|██████████| 6766258/6766258 [03:38<00:00, 30928.81it/s]

# %%
bim_like = pd.DataFrame({
    'CHROM': np.array(chr_ids)[~mask],
    'SNP_ID': np.array(snp_pos)[~mask],
    'GEN_DIST': ['0'] * np.sum(~mask),
    'POS': np.array(snp_pos)[~mask],
    'ALT': ref_alt[~mask][:, 1],
    'REF': ref_alt[~mask][:, 0]
})

# recode chromosome and SNP identifiers into integers
chr2int = dict(zip(list(dict.fromkeys(bim_like['CHROM'])), range(1, 1 + len(set(bim_like['CHROM'])))))
bim_like['CHROM'] = bim_like['CHROM'].replace(chr2int)

bim_like['CHROM'] = bim_like['CHROM'].astype(str)
bim_like['GEN_DIST'] = bim_like['GEN_DIST'].astype(str)
bim_like['SNP_ID'] = bim_like[["CHROM", "POS"]].agg(":".join, axis=1)
# Out:
# /tmp/ipykernel_2652648/1469035007.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bim_like['CHROM'] = bim_like['CHROM'].replace(chr2int)

# %%
bim_like
# Out:
#         CHROM      SNP_ID GEN_DIST      POS ALT REF
# 0           1      1:5671        0     5671   G   T
# 1           1      1:5698        0     5698   C   T
# 2           1      1:6621        0     6621   G   A
# 3           1      1:6717        0     6717   A   C
# 4           1      1:6823        0     6823   C   G
# ...       ...         ...      ...      ...  ..  ..
# 6766253    16  16:7225908        0  7225908   C   T
# 6766254    16  16:7225911        0  7225911   T   C
# 6766255    16  16:7226186        0  7226186   A   G
# 6766256    16  16:7226346        0  7226346   A   G
# 6766257    16  16:7227034        0  7227034   A   G
#
# [6766258 rows x 6 columns]

# %%
# %%time
bim_like.to_csv('{}{}.bim_like'.format(queen_geno_path, prefix), header=False, index=False, sep='\t')
# Out:
# CPU times: user 6.17 s, sys: 395 ms, total: 6.57 s
# Wall time: 6.73 s

# %% [markdown]
# ### Export count_ref.txt and depth.txt files

# %%
# TO DO: insert also alleles! --> aim to have same .bgs as Sonia!
# ,CHROM,POS,REF,ALT,BS16_0032...

# %%
# %%time
# creating depth dataframe # 30min...
depth_df = pd.DataFrame(depth[~mask])
# Out:
# CPU times: user 8.46 s, sys: 15.3 s, total: 23.8 s
# Wall time: 23.9 s

# %%
depth_df.insert(0, 'CHROM',  bim_like['CHROM'])
depth_df.insert(1, 'POS', bim_like['POS'])
depth_df.insert(2, 'REF',  bim_like['REF'])
depth_df.insert(3, 'ALT', bim_like['ALT'])
depth_df.columns = ['CHROM', 'POS', 'REF', 'ALT'] + bs_ids[batch_i: batch_ii]

# %%
# %%time
for gg in set(pheno_df['Genetic group']):
    print(gg)
    depth_df[['CHROM', 'POS', 'REF', 'ALT'] + list(pheno_df[pheno_df['Genetic group'] == gg]['Colony'])].to_csv('{}depth_{}.txt'.format(queen_geno_path, gg), header=True, index=False, sep='\t')
# Out:
# Caucasica
# hybrid
# Mellifera
# Ligustica_Carnica
# CPU times: user 23min 46s, sys: 2min 26s, total: 26min 13s
# Wall time: 26min 31s

# %%
# %%time
# getting the ref allele counts 5-8min...
count_ref  = np.max(count_mat[:, batch_i:batch_ii, :], axis = 2)

# creating reference allele count dataframe
count_ref_df = pd.DataFrame(count_ref[~mask])
count_ref_df.insert(0, 'CHROM',  bim_like['CHROM'])
count_ref_df.insert(1, 'POS', bim_like['POS'])
count_ref_df.insert(2, 'REF',  bim_like['REF'])
count_ref_df.insert(3, 'ALT', bim_like['ALT'])
count_ref_df.columns = ['CHROM', 'POS', 'REF', 'ALT'] + bs_ids[batch_i: batch_ii]
# Out:
# CPU times: user 4min 58s, sys: 4min 6s, total: 9min 4s
# Wall time: 9min 5s

# %%
# %%time
for gg in set(pheno_df['Genetic group']):
    print(gg)
    count_ref_df[['CHROM', 'POS', 'REF', 'ALT'] + list(pheno_df[pheno_df['Genetic group'] == gg]['Colony'])].to_csv('{}count_ref_{}.txt'.format(queen_geno_path, gg), header=True, index=False, sep='\t')
# Out:
# Caucasica
# hybrid
# Mellifera
# Ligustica_Carnica
# CPU times: user 22min 17s, sys: 1min 5s, total: 23min 22s
# Wall time: 23min 39s

# %% [markdown]
# ## Queen genotype reconstruction

# %%
def write_run_beethoven_script(script_fn):
    runstr="""#!/bin/bash -l
#SBATCH --cpus-per-task=10
#SBATCH --mem=40g
#SBATCH --time=48:00:00
#SBATCH --job-name=beethoven
#SBATCH --output=%x_%j.out
#SBATCH --error=%x_%j.err

modulesld
ebld
module use /software/anaconda3/envs/eb/easybuild/modules/all
conda activate planb

dir_in=$1
depth_file=$2
count_ref_file=$3
prefix=$4

genoqueen_hom ${dir_in} ${depth_file} ${count_ref_file} 4 10 ${prefix} 1000

echo DONE"""
    with open(script_fn, 'w') as outf:
        outf.write(runstr)

# %%
script_fn = '{}beethoven.run'.format(script_path)
write_run_beethoven_script(script_fn)

# %%
script_fn
# Out:
# '/cluster/raid/home/f80878961/scripts/tmp_scripts/beethoven.run'

# %%
gg = 'Caucasica'
command = ['sbatch', script_fn, queen_geno_path, 'depth_{}.txt'.format(gg), 'count_ref_{}.txt'.format(gg), '{}_{}'.format(prefix, gg)]
result = subprocess.run(command, cwd=queen_geno_path, capture_output=True, text=True)

# %%
for gg in set(pheno_df['Genetic group']):
    if gg == 'Caucasica':
        continue
    print(gg)
    command = ['sbatch', script_fn, queen_geno_path, 'depth_{}.txt'.format(gg), 'count_ref_{}.txt'.format(gg), '{}_{}'.format(prefix, gg)]
    result = subprocess.run(command, cwd=queen_geno_path, capture_output=True, text=True)
# Out:
# hybrid
# Mellifera
# Ligustica_Carnica

# %% [markdown]
# ## Write PLINK .ped

# %% [markdown]
# ### Split beethoven .prob files

# %%
prefix = 'queen'
plink_path = '{}data/queen_genotypes/hom_pop/'.format(working_path)
populations = ['Caucasica', 'Ligustica_Carnica', 'Mellifera', 'hybrid']
chunk_size = 25
prob_threshold = 0.95

# %%
# need to split .prob files into 3: AA, AR, RR --> easier to read probability of these genotypes simulateously then...
def split_prob_file(
    plink_path, prefix, pop):

    prob_file = '{}{}_{}.prob'.format(plink_path, prefix, pop)
    aa_file = '{}{}_{}_AA.prob'.format(plink_path, prefix, pop)
    ar_file = '{}{}_{}_AR.prob'.format(plink_path, prefix, pop)
    rr_file = '{}{}_{}_RR.prob'.format(plink_path, prefix, pop)
    
    out_aa = open(aa_file, 'w')
    out_ar = open(ar_file, 'w')
    out_rr = open(rr_file, 'w')
    
    with open(prob_file, 'r') as inf:
        headers = inf.readline()
        out_aa.write(headers.rstrip(',geno\n') + '\n')
        out_ar.write(headers.rstrip(',geno\n') + '\n')
        out_rr.write(headers.rstrip(',geno\n') + '\n')

        for l in tqdm(inf):
            split_line = l.rstrip().split(',')
            geno = split_line[-1]
            if geno == 'AA':
                out_aa.write(','.join(split_line[:-1]) + '\n')
            elif geno == 'AR':
                out_ar.write(','.join(split_line[:-1]) + '\n')
            elif geno == 'RR':
                out_rr.write(','.join(split_line[:-1]) + '\n')
            else: 
                print('GENO: {}'.format(geno))
                      
    out_aa.close()
    out_ar.close()
    out_rr.close()

# %%
for pop in populations:
    split_prob_file(plink_path, prefix, pop)
# Out:
# 20293116it [00:46, 437729.20it/s]
# 20293116it [24:53, 13589.27it/s]
# 20293116it [15:02, 22474.99it/s]
# 20293116it [14:04, 24026.43it/s]

# %% [markdown]
# ### Write .ped by population with probability threshold

# %% [markdown]
# debug

# %%
def write_ped_woprob(
    plink_path, prefix, pop, chunk_bs_ids, batch_j, chunk_size):
    
    # index of column with first bs_id (skipping metadata columns)
    bgs_col_idx = 5
    
    bim_like = pd.read_csv('{}{}.bim_like'.format(plink_path, prefix), sep='\t', header=None)
    bgs_file = '{}{}_{}.bgs'.format(plink_path, prefix, pop)
    snp_nr = len(bim_like)
    
    start_j = batch_j * chunk_size
    ped_mat = np.full((len(chunk_bs_ids), 2 * snp_nr), '', dtype='U1')
    
    inf = open(bgs_file, 'r')

    # check we have the same bs ids in header than in batch
    header_bsids = inf.readline()
    assert header_bsids.rstrip().split(',')[bgs_col_idx:][start_j: start_j + len(chunk_bs_ids)] == chunk_bs_ids, 'bs_id mismatch'

    # iterate snps and colonies
    for i in tqdm(range(snp_nr)):
        ref_numbers = inf.readline().rstrip().split(',')[bgs_col_idx:]

        for j in range(start_j, start_j + len(chunk_bs_ids)):
            ref_nr = ref_numbers[j]

            # homozygote reference
            if (ref_nr == '2'):
                ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 5]
                ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 5]
            # heterozygote
            elif (ref_nr == '1'):
                ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 5]
                ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 4]
            # homozygote alternative
            elif (ref_nr == '0'):
                ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 4]
                ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 4]
            # below prob_threshold
            elif ref_nr in {'0', '1', '2'}:
                ped_mat[j - start_j, 2 * i] = '0'
                ped_mat[j - start_j, 2 * i + 1] = '0'
            else: 
                print('ERROR')
            
    inf.close()

    ped_df = pd.DataFrame({
        'FID': ['0'] * len(chunk_bs_ids), 
        'IID': chunk_bs_ids,
        'PID': ['0'] * len(chunk_bs_ids),
        'MID': ['0'] * len(chunk_bs_ids),
        'SEX': ['0'] * len(chunk_bs_ids), 
        'PHENOTYPE': ['-9'] * len(chunk_bs_ids)
    })
    ped_df = ped_df.join(pd.DataFrame(ped_mat))
    ped_df.to_csv('{}{}_{}_{}.ped'.format(plink_path, prefix, pop, batch_j), header=False, index=False, sep='\t')

# %%
queen_geno_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)
plink_path = queen_geno_path
populations = ['Ligustica_Carnica', 'Mellifera']
populations = ['Ligustica_Carnica']
prob_threshold = 0

# %%
prefix = 'Sonia_All'
plink_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)
pop = 'Ligustica_Carnica'

# %%
batch_file = '{}bsid_batch_{}.txt'.format(plink_path, pop)
with open(batch_file, "r") as inf:
    batch_bs_ids = [x.rstrip().split(',') for x in inf.readlines()]
batch_file
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/Sonia_All/bsid_batch_Ligustica_Carnica.txt'

# %%
batch_file
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/Sonia_All/bsid_batch_Ligustica_Carnica.txt'

# %%
batch_j = 0
chunk_bs_ids = batch_bs_ids[batch_j]
chunk_size = 25

# %%
bim_like
# Out:
#              0           1         2        3    4    5
# 0        CHROM      SNP_ID  GEN_DIST      POS  ALT  REF
# 1            1      1:5671         0     5671    C    T
# 2            1      1:5698         0     5698    C    T
# 3            1      1:6621         0     6621    G    A
# 4            1      1:6717         0     6717    T    C
# ...        ...         ...       ...      ...  ...  ...
# 6831070     16  16:7225911         0  7225911    T    C
# 6831071     16  16:7225986         0  7225986    C    G
# 6831072     16  16:7226186         0  7226186    C    G
# 6831073     16  16:7226346         0  7226346    A    G
# 6831074     16  16:7227034         0  7227034    A    G
#
# [6831075 rows x 6 columns]

# %%
# index of column with first bs_id (skipping metadata columns)
bgs_col_idx = 5

bim_like = pd.read_csv('{}{}.bim_like'.format(plink_path, prefix), sep='\t', header=None)
bgs_file = '{}{}_{}.bgs'.format(plink_path, prefix, pop)
snp_nr = len(bim_like)

start_j = batch_j * chunk_size
ped_mat = np.full((len(chunk_bs_ids), 2 * snp_nr), '', dtype='U1')

inf = open(bgs_file, 'r')

# check we have the same bs ids in header than in batch
header_bsids = inf.readline()
assert header_bsids.rstrip().split(',')[bgs_col_idx:][start_j: start_j + len(chunk_bs_ids)] == chunk_bs_ids, 'bs_id mismatch'
# Out:
# /tmp/ipykernel_1824108/1242175706.py:4: DtypeWarning: Columns (0,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   bim_like = pd.read_csv('{}{}.bim_like'.format(plink_path, prefix), sep='\t', header=None)

# %%
# iterate snps and colonies
for i in tqdm(range(snp_nr)):
    ref_numbers = inf.readline().rstrip().split(',')[bgs_col_idx:]

    for j in range(start_j, start_j + len(chunk_bs_ids)):
        ref_nr = ref_numbers[j]

        # homozygote reference
        if (ref_nr == '2'):
            ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 5]
            ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 5]
        # heterozygote
        elif (ref_nr == '1'):
            ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 5]
            ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 4]
        # homozygote alternative
        elif (ref_nr == '0'):
            ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 4]
            ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 4]
        # below prob_threshold
        elif ref_nr in {'0', '1', '2'}:
            ped_mat[j - start_j, 2 * i] = '0'
            ped_mat[j - start_j, 2 * i + 1] = '0'
        else: 
            print('ERROR')
        
inf.close()

ped_df = pd.DataFrame({
    'FID': ['0'] * len(chunk_bs_ids), 
    'IID': chunk_bs_ids,
    'PID': ['0'] * len(chunk_bs_ids),
    'MID': ['0'] * len(chunk_bs_ids),
    'SEX': ['0'] * len(chunk_bs_ids), 
    'PHENOTYPE': ['-9'] * len(chunk_bs_ids)
})
ped_df = ped_df.join(pd.DataFrame(ped_mat))
ped_df.to_csv('{}{}_{}_{}.ped'.format(plink_path, prefix, pop, batch_j), header=False, index=False, sep='\t')

# %%
def write_write_ped_script(script_fn, array_str):
    runstr="""#!/bin/bash -l
#SBATCH --array=ARRAY_STRING
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --mem=50g
#SBATCH --time=6:00:00
#SBATCH --job-name=write_ped
#SBATCH --output=%x_%A_%a.out
#SBATCH --error=%x_%A_%a.err

modulesld
ebld
module use /software/anaconda3/envs/eb/easybuild/modules/all
conda activate planb

# file listing batches of BeeStrong ids (bs_id) for parallel computing
batch_file=$1
chunk_size=$2
plink_path=$3
prefix=$4
pop=$5
prob_threshold=$6
    
batch_id=$SLURM_ARRAY_TASK_ID

# getting bs_ids
chunk_bs_ids=$(sed -n ${batch_id}'{p;q}' ${batch_file})
    
python ~/scripts/plan-b-omics/bin/write_ped.py --chunk_bs_ids ${chunk_bs_ids} --batch_id ${batch_id} --chunk_size ${chunk_size} --plink_path ${plink_path} --prefix ${prefix} --pop ${pop} --prob_threshold ${prob_threshold}

echo DONE""".replace("ARRAY_STRING", array_str)
    with open(script_fn, 'w') as outf:
        outf.write(runstr)

# %%
queen_geno_path
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/All/'

# %%
chunk_size = 25
prefix = 'All'
populations = ['Caucasica', 'Ligustica_Carnica', 'Mellifera', 'hybrid']

# if threshold = 0, then the .prob files are not used
prob_threshold = 0

# %%
# write batch files
for pop in populations:
    batch_file = '{}bsid_batch_{}.txt'.format(plink_path, pop)
    bs_ids = pheno_df[pheno_df['Genetic group'] == pop]['Colony'].to_list()
    print(len(bs_ids))
    
    batch_bs_ids = []
    with open(batch_file, "w") as outf:
        for i in range(0, len(bs_ids), chunk_size):
            chunk = bs_ids[i:i+chunk_size]
            batch_bs_ids.append(chunk)
            outf.write(",".join(chunk) + "\n")
# Out:
# 703
# 407

# %%
### Sonia .bgs
def get_bs_ids_from_bgs(bgs_file, bgs_col_idx=5):
    with open(bgs_file, 'r') as inf:
        header_bsids = inf.readline()
    return header_bsids.rstrip().split(',')[bgs_col_idx:]

def write_bim_like_from_bgs(bgs_file, plink_path, prefix):
    '''
    basically takes the first few columns of the .bgs file to create a  bim like file (that I am using to compute ped files)
    '''
    bim_df = pd.read_csv(bgs_file, sep=',', usecols=range(5))
    bim_df['SNP_ID'] = bim_df['CHROM'].astype(str) + ':' + bim_df['POS'].astype(str)
    bim_df['GEN_DIST'] = ['0'] * len(bim_df)
    bim_df = bim_df[['CHROM', 'SNP_ID', 'GEN_DIST', 'POS', 'ALT', 'REF']]
    bim_df.to_csv('{}{}.bim_like'.format(plink_path, prefix), index=False, header=None, sep='\t')
    
chunk_size = 25

prefix = 'Sonia_All'
queen_geno_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)
plink_path = queen_geno_path
populations = ['Ligustica_Carnica', 'Mellifera']
populations = ['Ligustica_Carnica']
prob_threshold = 0

# write batch files (for Sonia)
for pop in populations:
    batch_file = '{}bsid_batch_{}.txt'.format(plink_path, pop)
    bs_ids = get_bs_ids_from_bgs('{}{}_{}.bgs'.format(plink_path, prefix, pop), bgs_col_idx=5)
    print(len(bs_ids))
    
    batch_bs_ids = []
    with open(batch_file, "w") as outf:
        for i in range(0, len(bs_ids), chunk_size):
            chunk = bs_ids[i:i+chunk_size]
            batch_bs_ids.append(chunk)
            outf.write(",".join(chunk) + "\n")
# Out:
# 821

# %%
write_bim_like_from_bgs('/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/Sonia_All/Sonia_All_Ligustica_Carnica.bgs', plink_path, prefix)

# %%
pop = 'Ligustica_Carnica'
# pop = 'Caucasica'
# pop = 'Mellifera'
# pop = 'hybrid'

batch_file = '{}bsid_batch_{}.txt'.format(plink_path, pop)
with open(batch_file, "r") as inf:
    batch_bs_ids = [x.rstrip().split(',') for x in inf.readlines()]
batch_file
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/Sonia_All/bsid_batch_Ligustica_Carnica.txt'

# %%
array_str = '1-{}'.format(len(batch_bs_ids)) if len(batch_bs_ids) > 1 else '1'
script_fn = '{}write_ped.run'.format(script_path)
write_write_ped_script(script_fn, array_str)

# %%
# %%bash -s "$script_fn" "$batch_file" "$chunk_size" "$plink_path" "$prefix" "$pop" "$prob_threshold"
# cd $4
# sbatch $1 $2 $3 $4 $5 $6 $7
# Out:
# Submitted batch job 1390200

# %% [markdown]
# cat the ped files

# %% [markdown]
# ### Write PLINK .map files

# %% [markdown]
# .map file is also needed to convert ped to bed (only map + bed)
#
# CHR   SNP_ID   GEN_DIST   BP_POS
#
# basically bim wihout REF and ALT

# %%
prefix = 'All'
prefix = 'Sonia_All'
queen_geno_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)
populations = ['Ligustica_Carnica']

# %%
bim_like = pd.read_csv('{}{}.bim_like'.format(queen_geno_path, prefix), sep='\t', header=None)

# %%
for pop in populations:
    print(pop)
    bim_like[[0, 1, 2, 3]].to_csv('{}{}_{}.map'.format(queen_geno_path, prefix, pop), header=False, index=False, sep='\t')
# Out:
# Ligustica_Carnica

# %% [markdown]
# convert to bed in CLI. Not sure how long it will take for convertion to bed...
#
# ml PLINK
#
# plink --file queen --make-bed --out queen --allow-extra-chr

# %% [markdown]
# ## GREML H2 analyses

# %%
plink_path = '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/{}/'.format(plink_prefix)

plink_prefix = 'hom_pop'

plink_files = '{}{}'.format(plink_path, plink_prefix)

gcta_path = '/cluster/raid/home/f80878961/bin/gcta-1.95.0-linux-kernel-3-x86_64/gcta64' # cluster version fails for GRM 

greml_path = '/cluster/raid/home/f80878961/beestrong/data/heritability_greml/{}/'.format(plink_prefix)


lod = np.log(5e-06)

populations = ['Mellifera', 'Ligustica_Carnica', 'hybrid']

# %% [markdown]
# ### Compute GRMs

# %%
plink_prefix = 'hom_pop'
plink_files = '{}{}'.format(plink_path, plink_prefix)

pop = 'all_pops'
maf = 0.01

grm_path = '{}{}/GRM_maf{}/'.format(greml_path, pop, str(maf).replace('.', ''))
if not os.path.exists(grm_path):
    os.makedirs(grm_path)
        
grm_files = '{}{}'.format(grm_path, plink_prefix)

# %%
# %%bash -s "$grm_path" "$gcta_path" "$plink_files" "$maf" "$grm_files"
# mkdir -p $1
# cd $1
# $2 --bfile $3 --make-grm --maf $4 --out $5
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:24:25 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Options:
#
# --bfile /cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/hom_pop
# --make-grm
# --maf 0.05
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/all_pops/GRM_maf005/hom_pop
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/hom_pop.fam]...
# 1442 individuals to be included from FAM file.
# 1442 individuals to be included. 0 males, 0 females, 1442 unknown.
# Reading PLINK BIM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/hom_pop.bim]...
# 6764372 SNPs to be included from BIM file(s).
# Threshold to filter variants: MAF > 0.050000.
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-1442
#   1442 samples, 6764372 markers, 1040403 GRM elements
# IDs for the GRM file have been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/all_pops/GRM_maf005/hom_pop.grm.id]
# Computing GRM...
#   100% finished in 275.8 sec
# 6764372 SNPs have been processed.
#   Used 1801792 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/all_pops/GRM_maf005/hom_pop.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/all_pops/GRM_maf005/hom_pop.grm.N.bin]
#
# Analysis finished at 14:29:07 CET on Fri Jan 09 2026
# Overall computational time: 4 minutes 42 sec.

# %%
greml_path
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/'

# %%
str(maf)
# Out:
# '0.05'

# %%
maf = 0.05
plink_prefix = 'queen'
for pop in populations:
    print(pop)
    plink_files = '{}{}_{}'.format(plink_path, plink_prefix, pop)
    
    grm_path = '{}{}/GRM_maf{}/'.format(greml_path, pop, str(maf).replace('.', ''))
    if not os.path.exists(grm_path):
        os.makedirs(grm_path)
    grm_files = '{}{}'.format(grm_path, plink_prefix)
    
    command = [gcta_path, '--bfile', plink_files, '--make-grm', '--maf' , str(maf), '--out', grm_files]
    result = subprocess.run(command, cwd=grm_path, capture_output=True, text=True)
    print(result.stderr)
    print(result.stdout)
# Out:
# Mellifera
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:25:05 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Options:
#
# --bfile /cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Mellifera
# --make-grm
# --maf 0.05
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Mellifera/GRM_maf005/queen
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Mellifera.fam]...
# 405 individuals to be included from FAM file.
# 405 individuals to be included. 0 males, 0 females, 405 unknown.
# Reading PLINK BIM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Mellifera.bim]...
# 6764372 SNPs to be included from BIM file(s).
# Threshold to filter variants: MAF > 0.050000.
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-405
#   405 samples, 6764372 markers, 82215 GRM elements
# IDs for the GRM file have been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Mellifera/GRM_maf005/queen.grm.id]
# Computing GRM...
#   100% finished in 26.2 sec
# 6764372 SNPs have been processed.
#   Used 1553315 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Mellifera/GRM_maf005/queen.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Mellifera/GRM_maf005/queen.grm.N.bin]
#
# Analysis finished at 15:25:38 CET on Fri Jan 09 2026
# Overall computational time: 33.04 sec.
#
# Ligustica_Carnica
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:25:38 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Options:
#
# --bfile /cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Ligustica_Carnica
# --make-grm
# --maf 0.05
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Ligustica_Carnica.fam]...
# 645 individuals to be included from FAM file.
# 645 individuals to be included. 0 males, 0 females, 645 unknown.
# Reading PLINK BIM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Ligustica_Carnica.bim]...
# 6764372 SNPs to be included from BIM file(s).
# Threshold to filter variants: MAF > 0.050000.
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-645
#   645 samples, 6764372 markers, 208335 GRM elements
# IDs for the GRM file have been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen.grm.id]
# Computing GRM...
#   100% finished in 61.5 sec
# 6764372 SNPs have been processed.
#   Used 1718847 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen.grm.N.bin]
#
# Analysis finished at 15:26:46 CET on Fri Jan 09 2026
# Overall computational time: 1 minute 8 sec.
#
# hybrid
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:26:46 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Options:
#
# --bfile /cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_hybrid
# --make-grm
# --maf 0.05
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_hybrid.fam]...
# 372 individuals to be included from FAM file.
# 372 individuals to be included. 0 males, 0 females, 372 unknown.
# Reading PLINK BIM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_hybrid.bim]...
# 6764372 SNPs to be included from BIM file(s).
# Threshold to filter variants: MAF > 0.050000.
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-372
#   372 samples, 6764372 markers, 69378 GRM elements
# IDs for the GRM file have been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id]
# Computing GRM...
#   100% finished in 23.8 sec
# 6764372 SNPs have been processed.
#   Used 1931679 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.N.bin]
#
# Analysis finished at 15:27:17 CET on Fri Jan 09 2026
# Overall computational time: 30.44 sec.

# %% [markdown]
# Create input for GREML analyses
# 1. phenotype file .phen
# 2. categorical variables .covar
# 3. continuous variables .qcovar

# %%
def write_pheno_file(h2_path, h2_name, gcta_df, phenotype):
    fn = '{}{}.phen'.format(h2_path, h2_name)
    gcta_df[['0', 'Colony', phenotype]].fillna('NA').to_csv(fn, header=None, sep='\t', index=False)

def write_covar_file(h2_path, h2_name, gcta_df, fixed_covar, tax_covar):

    temp_gcta_df = gcta_df.copy()
    
    # replace abundance values by presence-absence for prevalence associations
    temp_gcta_df[temp_gcta_df[tax_covar] >= lod] = int(1)
    temp_gcta_df[temp_gcta_df[tax_covar] < lod] = int(0)

    fn = '{}{}.covar'.format(h2_path, h2_name)
    temp_gcta_df[['0', 'Colony'] + fixed_covar + tax_covar].to_csv(fn, header=None, sep='\t', index=False)

def write_qcovar_file(h2_path, h2_name, gcta_df, fixed_qcovar, tax_qcovar):
    fn = '{}{}.qcovar'.format(h2_path, h2_name)
    gcta_df[['0', 'Colony'] + fixed_qcovar + tax_qcovar].to_csv(fn, header=None, sep='\t', index=False)

# %% [markdown]
# Combine metadata and symbiosphere data

# %%
pheno_df = pd.read_csv('{}BeeStrong_metadata.csv'.format(tlf_path))
abund_df = pd.read_csv('{}Core_Family_LRA.csv'.format(tlf_path))
pca_df = pd.read_csv('{}PCA_Core_Family_LRA.csv'.format(tlf_path))

gcta_df = pheno_df.merge(abund_df, on='Colony').merge(pca_df.rename(columns={'Unnamed: 0': 'Colony'}), on='Colony')
gcta_df.insert(0, '0', [0] * len(gcta_df))

# reorder pheno df according to fam_df (order disrupted due to per-population genotype inference)
fam_df = pd.read_csv('{}hom_pop.fam'.format(plink_path), header=None, sep='\s') 
gcta_df = gcta_df.set_index("Colony").loc[fam_df[1].to_list()].reset_index()

# check consistent colony order between pheno df and plink
bs_ids = gcta_df['Colony'].to_list()
assert fam_df[1].to_list() == bs_ids, 'messed up colony order'

gcta_df
# Out:
# /tmp/ipykernel_2233136/1970459003.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   fam_df = pd.read_csv('{}hom_pop.fam'.format(plink_path), header=None, sep='\s')
#          Colony  0        date Genetic group  percent_Ligustica_Carnica  \
# 0     BS16_0060  0  06/07/2016     Caucasica                   0.118259
# 1     BS16_0061  0  06/07/2016     Caucasica                   0.109495
# 2     BS16_0162  0  31/08/2016     Caucasica                   0.047143
# 3     BS16_0163  0  31/08/2016     Caucasica                   0.015421
# 4     BS16_0164  0  31/08/2016     Caucasica                   0.005619
# ...         ... ..         ...           ...                        ...
# 1437  BS17_0506  0  01/08/2017        hybrid                   0.418368
# 1438  BS17_0511  0  01/08/2017        hybrid                   0.044593
# 1439  BS17_0512  0  01/08/2017        hybrid                   0.113869
# 1440  BS17_0513  0  01/08/2017        hybrid                   0.554205
# 1441  BS17_0517  0  01/08/2017        hybrid                   0.378583
#
#       percent_Mellifera  percent_Caucasica  bee_weigth  nbr_pho_varroa  \
# 0          1.369552e-04           0.881604        51.0             0.0
# 1          9.200239e-05           0.890413        52.0             1.0
# 2          1.376441e-05           0.952843        63.0            28.0
# 3          1.019360e-05           0.984569        52.0             2.0
# 4          4.687815e-08           0.994381        60.0             9.0
# ...                 ...                ...         ...             ...
# 1437       5.687723e-01           0.012860        47.5             1.0
# 1438       7.929777e-01           0.162429        41.0             0.0
# 1439       5.741510e-01           0.311980        39.2             0.0
# 1440       4.213804e-01           0.024415        43.0             0.0
# 1441       2.230246e-01           0.398393        56.0             5.0
#
#       nbr_pho_varroa_100bee  ...      PC58      PC59      PC60      PC61  \
# 0                       0.0  ... -0.223545  0.611330  0.302651  0.131466
# 1                       0.0  ...  1.083837  0.319977 -0.277766  0.184884
# 2                       6.0  ...  0.114503 -0.171535 -0.115155  0.327699
# 3                       1.0  ... -0.256039 -0.478161  0.069915  0.570721
# 4                       2.0  ... -0.114564 -0.172282  0.017520  0.432423
# ...                     ...  ...       ...       ...       ...       ...
# 1437                    0.0  ... -0.185675 -0.057137 -0.014365  0.275159
# 1438                    0.0  ... -0.049772  0.183526 -0.083507 -0.102922
# 1439                    0.0  ...  0.277892 -0.524994  0.025260  0.413383
# 1440                    0.0  ...  0.616182  0.201392 -0.425561  0.144140
# 1441                    1.0  ... -0.389531 -0.027292  0.023136  0.123168
#
#           PC62      PC63      PC64      PC65      PC66      PC67
# 0    -0.060962  0.205536 -0.101299 -0.252870  0.160926  0.010749
# 1    -0.267314 -0.058724  0.008251 -0.107998 -0.273400  0.016922
# 2     0.127601 -0.413191  0.045553 -0.106437  0.230031  0.392338
# 3    -0.081693  0.135746  0.021538 -0.012105 -0.083352 -0.242981
# 4    -0.139529 -0.082052  0.020244 -0.335893  0.113096  0.116470
# ...        ...       ...       ...       ...       ...       ...
# 1437  0.384569 -0.180188  0.010630  0.194236  0.054757 -0.261595
# 1438 -0.160323  0.213182  0.103019 -0.118458 -0.101629 -0.220722
# 1439 -0.185017 -0.411371 -0.207086  0.299036  0.171580  0.535910
# 1440 -0.430934  0.012346 -0.186331  0.307234  0.191650  0.425309
# 1441  0.229125 -0.110197  0.135449 -0.078937 -0.107581 -0.052356
#
# [1442 rows x 179 columns]

# %%
set(gcta_df['Genetic group'])
# Out:
# {'Caucasica', 'Ligustica_Carnica', 'Mellifera', 'hybrid'}

# %%
# maf = '001'
maf = '005'

pop = 'Mellifera'
pop = 'Ligustica_Carnica'
pop = 'hybrid'
# pop = 'all_pops'

if pop == 'all_pops':
    pop_gcta_df = gcta_df
    plink_prefix = 'hom_pop'
else:
    pop_gcta_df = gcta_df[gcta_df['Genetic group'] == pop]
    plink_prefix = 'queen'

default_covar = ['Apiary', 'Year']
default_qcovar = ['Day of Year']
vaf_prev = [
    'Oscillospiraceae',
    'Corynebacteriaceae',
    'Cannabaceae',
    'Aeromonadaceae',
    'Weeksellaceae',
    'Araliaceae',
    'Actinomycetaceae',
    'Trypanosomatidae',
    'Saccharomycodaceae', # v_pho specific
]
vaf_abund = [
    'Bifidobacteriaceae',
    'Lactobacillaceae',
    'Pseudomonadaceae',   
    'Debaryomycetaceae',
    'Bartonellaceae',  
    'Morganellaceae',
    'Rosaceae', # v_pho specific
    'Microbacteriaceae',  # v_pho specific
    'Enterobacteriaceae',  # v_pho specific
    'Nosematidae' # v_pho specific
]

top5vaf_prev = [
   'Oscillospiraceae',
    'Cannabaceae',
    'Trypanosomatidae'
]
top5vaf_abund = [
    'Bartonellaceae',  
    'Morganellaceae'
]

name2settings = {
    'default_v_meta': ('log_v_meta', default_covar, [], default_qcovar, []),
    'default_v_pho': ('log_v_pho', default_covar, [], default_qcovar, []),
    'default_DMR': ('DMR', default_covar, [], default_qcovar, []),
    'default_Recapping': ('Recapping', default_covar, [], default_qcovar, []),
    #'VAF_v_meta': ('log_v_meta', default_covar, vaf_prev, default_qcovar, vaf_abund),
    #'VAF_v_pho': ('log_v_pho', default_covar, vaf_prev, default_qcovar, vaf_abund),
    #'top5VAF_v_meta': ('log_v_meta', default_covar, top5vaf_prev, default_qcovar, top5vaf_abund),
    #'top5VAF_v_pho': ('log_v_pho', default_covar, top5vaf_prev, default_qcovar, top5vaf_abund),
    #'1PC_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 2)]),
    #'1PC_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 2)]),
    #'1PC_DMR': ('DMR', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 2)]),
    #'1PC_Recapping': ('Recapping', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 2)]),
    #'2PC_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 3)]),
    #'2PC_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 3)]),
    #'2PC_DMR': ('DMR', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 3)]),
    #'2PC_Recapping': ('Recapping', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 3)]),
    #'3PC_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 4)]),
    #'3PC_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 4)]),
    #'3PC_DMR': ('DMR', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 4)]),
    #'3PC_Recapping': ('Recapping', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 4)]),
    '4PC_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 5)]),
    '4PC_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 5)]),
    '4PC_DMR': ('DMR', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 5)]),
    '4PC_Recapping': ('Recapping', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 5)]),
    # '5PC_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 6)]),
    # '5PC_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 6)]),
    # '5PC_DMR': ('DMR', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 6)]),
    # '5PC_Recapping': ('Recapping', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 6)]),
    # '10PC_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 11)]),
    # '10PC_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 11)]),
    # '10PC_DMR': ('DMR', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 11)]),
    # '10PC_Recapping': ('Recapping', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 11)]),
    # '15PC_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 16)]),
    # '15PC_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 16)]),
    # '15PC_DMR': ('DMR', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 16)]),
    # '15PC_Recapping': ('Recapping', default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, 16)]),
    # 'PC5_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC5']), # 5, 1, 4, are the most associated with Varroa
    # 'PC5_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC5']),
    # 'PC145_v_meta': ('log_v_meta', default_covar, [], default_qcovar, ['PC1', 'PC4', 'PC5']),
    # 'PC145_v_pho': ('log_v_pho', default_covar, [], default_qcovar, ['PC1', 'PC4', 'PC5']),
}

# %%
grm_files
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen'

# %%
grm_path = '{}{}/GRM_maf{}/'.format(greml_path, pop, maf)
grm_files = '{}{}'.format(grm_path, plink_prefix)

for h2_name, (phenotype, fixed_covar, tax_covar, fixed_qcovar, tax_qcovar) in name2settings.items():
    print(h2_name)
    h2_path = '{}{}/{}/{}/'.format(greml_path, pop, maf, h2_name)

    if not os.path.exists(h2_path):
        os.makedirs(h2_path)
        
    write_pheno_file(h2_path, h2_name, pop_gcta_df, phenotype)
    write_covar_file(h2_path, h2_name, pop_gcta_df, fixed_covar, tax_covar)
    write_qcovar_file(h2_path, h2_name, pop_gcta_df, fixed_qcovar, tax_qcovar)

    command = [gcta_path, '--reml', '--grm',  grm_files , '--pheno', '{}{}.phen'.format(h2_path, h2_name), '--covar', '{}{}.covar'.format(h2_path, h2_name), 
           '--qcovar', '{}{}.qcovar'.format(h2_path, h2_name), '--out', '{}{}'.format(h2_path, h2_name)]
    result = subprocess.run(command, cwd=greml_path, capture_output=True, text=True)
    print(result.stderr)
    print(result.stdout)
# Out:
# default_v_meta
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:29:37 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.qcovar].
# 1 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.covar].
#
# 1 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 87 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.998379 0.903929
# logL: -223.86
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-214.18	0.94199	0.73502
# 2	-209.06	0.91513	0.65515
# 3	-207.31	0.90230	0.60876
# 4	-206.62	0.89691	0.57907
# 5	-206.32	0.89282	0.51541
# 6	-206.08	0.91226	0.50787
# 7	-206.07	0.91943	0.50372
# 8	-206.07	0.92252	0.50192
# 9	-206.07	0.92386	0.50114
# 10	-206.07	0.92444	0.50081
# 11	-206.07	0.92469	0.50066
# 12	-206.07	0.92480	0.50060
# 13	-206.07	0.92484	0.50057
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.35458
# logL: -238.47856
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-210.70	1.24392
# 2	-208.63	1.18271
# 3	-207.82	1.14577
# 4	-207.48	1.07184
# 5	-207.20	1.07630
# 6	-207.20	1.07632
# 7	-207.20	1.07632
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.924843	0.449088
# V(e)	0.500575	0.260348
# Vp	1.425417	0.220530
# V(G)/Vp	0.648822	0.225940
#
# Sampling variance/covariance of the estimates of variance components:
# 2.016796e-01	-1.104135e-01
# -1.104135e-01	6.778099e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_meta/default_v_meta.hsq].
#
# Analysis finished at 15:29:38 CET on Fri Jan 09 2026
# Overall computational time: 0.19 sec.
#
# default_v_pho
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:29:38 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.phen].
# Non-missing phenotypes of 349 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.qcovar].
# 1 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.covar].
#
# 1 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 349 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 349 observations, 80 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values:  0.74376 0.666304
# logL: -170.017
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-159.83	0.74078	0.50567
# 2	-154.20	0.71556	0.44700
# 3	-152.39	0.69637	0.41734
# 4	-151.68	0.68305	0.40034
# 5	-151.38	0.65418	0.36751
# 6	-151.14	0.65345	0.37084
# 7	-151.13	0.65384	0.37062
# 8	-151.13	0.65380	0.37065
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.00466
# logL: -185.81501
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-158.96	0.92290
# 2	-157.02	0.87763
# 3	-156.26	0.85030
# 4	-155.94	0.79559
# 5	-155.69	0.79889
# 6	-155.69	0.79890
# 7	-155.69	0.79890
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.653797	0.263715
# V(e)	0.370649	0.153433
# Vp	1.024446	0.139177
# V(G)/Vp	0.638196	0.184471
#
# Sampling variance/covariance of the estimates of variance components:
# 6.954560e-02	-3.685858e-02
# -3.685858e-02	2.354173e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_v_pho/default_v_pho.hsq].
#
# Analysis finished at 15:29:38 CET on Fri Jan 09 2026
# Overall computational time: 0.20 sec.
#
# default_DMR
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:29:38 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.phen].
# Non-missing phenotypes of 343 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.qcovar].
# 1 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.covar].
#
# 1 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 343 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 343 observations, 79 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.0195642 0.0207123
# logL: 255.019
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	256.30	0.01280	0.02530
# 2	257.51	0.00846	0.02845
# 3	258.10	0.00599	0.03039
# 4	258.35	0.00154	0.03418
# 5	258.56	0.00175	0.03416
# 6	258.56	0.00182	0.03412
# 7	258.56	0.00184	0.03411
# 8	258.56	0.00184	0.03410
# 9	258.56	0.00184	0.03410
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.03593
# logL: 258.22042
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	258.51	0.03574
# 2	258.52	0.03534
# 3	258.53	0.03535
# 4	258.53	0.03535
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.001844	0.006261
# V(e)	0.034103	0.005080
# Vp	0.035948	0.003789
# V(G)/Vp	0.051304	0.171057
#
# Sampling variance/covariance of the estimates of variance components:
# 3.919742e-05	-2.532547e-05
# -2.532547e-05	2.580643e-05
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_DMR/default_DMR.hsq].
#
# Analysis finished at 15:29:38 CET on Fri Jan 09 2026
# Overall computational time: 0.10 sec.
#
# default_Recapping
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:29:38 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.phen].
# Non-missing phenotypes of 350 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.qcovar].
# 1 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.covar].
#
# 1 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 350 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 350 observations, 80 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values:  1.11273 0.959556
# logL: -215.109
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-198.31	1.33359	0.45096
# 2	-185.47	1.30529	0.34545
# 3	-182.55	1.27521	0.29940
# 4	-181.48	1.25332	0.27475
# 5	-181.04	1.23825	0.26022
# 6	-180.85	1.20575	0.23158
# 7	-180.69	1.20612	0.23359
# 8	-180.69	1.20610	0.23361
# 9	-180.69	1.20610	0.23361
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.37803
# logL: -233.88258
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-193.83	1.21853
# 2	-190.15	1.13838
# 3	-188.84	1.09209
# 4	-188.30	1.06353
# 5	-188.07	1.00561
# 6	-187.89	1.00859
# 7	-187.89	1.00860
# 8	-187.89	1.00860
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.206103	0.360139
# V(e)	0.233611	0.193759
# Vp	1.439714	0.196216
# V(G)/Vp	0.837738	0.151002
#
# Sampling variance/covariance of the estimates of variance components:
# 1.297000e-01	-6.437096e-02
# -6.437096e-02	3.754271e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/default_Recapping/default_Recapping.hsq].
#
# Analysis finished at 15:29:38 CET on Fri Jan 09 2026
# Overall computational time: 0.14 sec.
#
# 4PC_v_meta
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:29:39 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.qcovar].
# 5 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.covar].
#
# 5 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 91 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values:  1.00219 0.909588
# logL: -235.071
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-225.89	0.96777	0.72862
# 2	-220.91	0.94980	0.64368
# 3	-219.21	0.94168	0.59456
# 4	-218.53	0.93911	0.56324
# 5	-218.24	0.94069	0.49629
# 6	-218.00	0.96004	0.48884
# 7	-218.00	0.96632	0.48522
# 8	-218.00	0.96873	0.48383
# 9	-218.00	0.96966	0.48329
# 10	-218.00	0.97001	0.48309
# 11	-218.00	0.97015	0.48301
# 12	-218.00	0.97020	0.48298
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.37581
# logL: -249.47406
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-222.99	1.26055
# 2	-220.85	1.19716
# 3	-220.02	1.15901
# 4	-219.67	1.08279
# 5	-219.40	1.08747
# 6	-219.39	1.08749
# 7	-219.39	1.08749
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.970201	0.453567
# V(e)	0.482977	0.261598
# Vp	1.453177	0.224203
# V(G)/Vp	0.667641	0.220753
#
# Sampling variance/covariance of the estimates of variance components:
# 2.057227e-01	-1.119446e-01
# -1.119446e-01	6.843347e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_meta/4PC_v_meta.hsq].
#
# Analysis finished at 15:29:39 CET on Fri Jan 09 2026
# Overall computational time: 0.18 sec.
#
# 4PC_v_pho
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:29:39 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.phen].
# Non-missing phenotypes of 349 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.qcovar].
# 5 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.covar].
#
# 5 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 349 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 349 observations, 84 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.746717 0.672319
# logL: -181.98
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-172.45	0.72971	0.52240
# 2	-167.14	0.70164	0.46556
# 3	-165.40	0.68157	0.43637
# 4	-164.71	0.66794	0.41949
# 5	-164.42	0.63874	0.38667
# 6	-164.19	0.63836	0.38979
# 7	-164.19	0.63869	0.38961
# 8	-164.19	0.63865	0.38963
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.02112
# logL: -197.21990
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-171.64	0.93552
# 2	-169.62	0.88845
# 3	-168.84	0.86013
# 4	-168.51	0.80353
# 5	-168.25	0.80701
# 6	-168.25	0.80703
# 7	-168.25	0.80703
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.638647	0.269962
# V(e)	0.389628	0.158129
# Vp	1.028276	0.141498
# V(G)/Vp	0.621086	0.190653
#
# Sampling variance/covariance of the estimates of variance components:
# 7.287946e-02	-3.893127e-02
# -3.893127e-02	2.500488e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_v_pho/4PC_v_pho.hsq].
#
# Analysis finished at 15:29:39 CET on Fri Jan 09 2026
# Overall computational time: 0.20 sec.
#
# 4PC_DMR
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:29:39 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.phen].
# Non-missing phenotypes of 343 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.qcovar].
# 5 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.covar].
#
# 5 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 343 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 343 observations, 83 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.0195906 0.0207001
# logL: 237.199
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	238.48	0.01323	0.02511
# 2	239.57	0.00923	0.02808
# 3	240.10	0.00695	0.02992
# 4	240.32	0.00283	0.03353
# 5	240.49	0.00330	0.03333
# 6	240.50	0.00336	0.03329
# 7	240.50	0.00336	0.03329
# 8	240.50	0.00336	0.03329
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.03611
# logL: 240.11155
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	240.35	0.03593
# 2	240.36	0.03554
# 3	240.36	0.03555
# 4	240.36	0.03555
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.003361	0.007070
# V(e)	0.033289	0.005427
# Vp	0.036650	0.004066
# V(G)/Vp	0.091707	0.186516
#
# Sampling variance/covariance of the estimates of variance components:
# 4.998908e-05	-3.145425e-05
# -3.145425e-05	2.945029e-05
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_DMR/4PC_DMR.hsq].
#
# Analysis finished at 15:29:39 CET on Fri Jan 09 2026
# Overall computational time: 0.10 sec.
#
# 4PC_Recapping
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:29:40 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.phen].
# Non-missing phenotypes of 350 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.qcovar].
# 5 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.covar].
#
# 5 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 350 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 350 observations, 84 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values:  1.11528 0.962868
# logL: -225.137
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-208.65	1.35869	0.43006
# 2	-195.43	1.32651	0.32695
# 3	-192.53	1.29365	0.28265
# 4	-191.47	1.26995	0.25916
# 5	-191.03	1.25364	0.24540
# 6	-190.84	1.21847	0.21843
# 7	-190.69	1.21856	0.22059
# 8	-190.69	1.21859	0.22058
# 9	-190.69	1.21859	0.22058
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.39637
# logL: -243.94485
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-204.95	1.22662
# 2	-201.01	1.14275
# 3	-199.61	1.09465
# 4	-199.05	1.06507
# 5	-198.81	1.00524
# 6	-198.62	1.00842
# 7	-198.62	1.00843
# 8	-198.62	1.00843
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.218591	0.360156
# V(e)	0.220582	0.193205
# Vp	1.439173	0.196705
# V(G)/Vp	0.846730	0.149781
#
# Sampling variance/covariance of the estimates of variance components:
# 1.297124e-01	-6.417383e-02
# -6.417383e-02	3.732800e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/005/4PC_Recapping/4PC_Recapping.hsq].
#
# Analysis finished at 15:29:40 CET on Fri Jan 09 2026
# Overall computational time: 0.14 sec.

# %%
maf = '001'
maf = '005'

pop = 'Mellifera'
# pop = 'Ligustica_Carnica'
#pop = 'hybrid'
# pop = 'all_pops'

phenotypes = ['v_meta', 'v_pho', 'Recapping', 'DMR']

# settings = ['default', 'VAF', 'top5VAF', '1PC', '2PC', '3PC', '4PC', '5PC', '10PC', '15PC', 'PC5', 'PC145']
settings = ['default', '4PC']

pheno2h2_list = defaultdict(list)
pheno2se_list = defaultdict(list)
pheno2pv_list = defaultdict(list)

for pheno in phenotypes:
    for sett in settings:
        h2_name = '{}_{}'.format(sett, pheno)
        h2_path = '{}{}/{}/{}/'.format(greml_path, pop, maf, h2_name)
        hsq_fn = '{}{}.hsq'.format(h2_path, h2_name)
        if not os.path.exists(hsq_fn): 
            h2 = np.nan
            se = np.nan
            pv = np.nan
        else:
            h2 = pd.read_table(hsq_fn).iloc[3, 1]
            se = pd.read_table(hsq_fn).iloc[3, 2]
            pv = pd.read_table(hsq_fn).iloc[8, 1]
            
        pheno2h2_list[pheno].append(h2)
        pheno2se_list[pheno].append(se)
        pheno2pv_list[pheno].append(pv)

# %%
h2_df = pd.DataFrame(pheno2h2_list)
h2_df.insert(0, 'setting', settings)
HTML(h2_df.round(3).to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>setting</th>
#       <th>v_meta</th>
#       <th>v_pho</th>
#       <th>Recapping</th>
#       <th>DMR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.669</td>
#       <td>0.762</td>
#       <td>0.673</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <td>4PC</td>
#       <td>0.621</td>
#       <td>0.703</td>
#       <td>0.629</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
se_df = pd.DataFrame(pheno2se_list)
se_df.insert(0, 'setting', settings)
HTML(se_df.round(3).to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>setting</th>
#       <th>v_meta</th>
#       <th>v_pho</th>
#       <th>Recapping</th>
#       <th>DMR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.159</td>
#       <td>0.150</td>
#       <td>0.165</td>
#       <td>0.132</td>
#     </tr>
#     <tr>
#       <td>4PC</td>
#       <td>0.170</td>
#       <td>0.164</td>
#       <td>0.174</td>
#       <td>0.138</td>
#     </tr>
#   </tbody>
# </table>

# %%
pv_df = pd.DataFrame(pheno2pv_list)
pv_df.insert(0, 'setting', settings)
HTML(pv_df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>setting</th>
#       <th>v_meta</th>
#       <th>v_pho</th>
#       <th>Recapping</th>
#       <th>DMR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.006356</td>
#       <td>0.000906</td>
#       <td>0.000117</td>
#       <td>0.33356</td>
#     </tr>
#     <tr>
#       <td>5PC</td>
#       <td>0.005243</td>
#       <td>0.001364</td>
#       <td>0.000022</td>
#       <td>0.30143</td>
#     </tr>
#   </tbody>
# </table>

# %%
pv_df = pd.DataFrame(pheno2pv_list)
pv_df.insert(0, 'setting', settings)
pv_df
# Out:
#    setting    v_meta         v_pho Recapping      DMR
# 0  default  0.000009  3.039900e-06       0.0  0.35711
# 1      VAF  0.000067  2.402300e-05        NA       NA
# 2  top5VAF  0.000021  2.408800e-06        NA       NA
# 3      5PC  0.000005  7.916900e-07       0.0  0.35697
# 4     10PC  0.000007  1.099400e-06       0.0  0.36479
# 5     15PC  0.000008  1.302400e-06       0.0   0.3471
# 6      PC5  0.000009  2.914100e-06        NA       NA
# 7    PC145  0.000008  1.559800e-06        NA       NA

# %%
res_df = pd.DataFrame(pheno2h2_list)
res_df.insert(0, 'setting', settings)

# %%
pd.read_table(hsq_fn)
# Out:
#     Source     Variance        SE
# 0     V(G)     0.000544  0.001827
# 1     V(e)     0.036814  0.002078
# 2       Vp     0.037358  0.001625
# 3  V(G)/Vp     0.014569  0.048732
# 4     logL  1159.177000       NaN
# 5    logL0  1159.109000       NaN
# 6      LRT     0.134000       NaN
# 7       df     1.000000       NaN
# 8     Pval     0.357110       NaN
# 9        n  1280.000000       NaN

# %%
['PC{}'.format(x) for x in range(1, 6)]
# Out:
# ['PC1', 'PC2', 'PC3', 'PC4', 'PC5']

# %%
phenotype = 'log_v_meta'
fixed_covar = ['Apiary', 'Year']
fixed_qcovar = ['Day of Year']
tax_covar = []
tax_qcovar = []
tax_covar = [
    'Oscillospiraceae',
    'Corynebacteriaceae',
    'Cannabaceae',
    'Aeromonadaceae',
    'Weeksellaceae',
    'Araliaceae',
    'Actinomycetaceae',
    'Trypanosomatidae',
    'Saccharomycodaceae', # v_pho specific
]
tax_qcovar = [
    'Bifidobacteriaceae',
    'Lactobacillaceae',
    'Pseudomonadaceae',   
    'Debaryomycetaceae',
    'Bartonellaceae',  
    'Morganellaceae',
    'Rosaceae', # v_pho specific
    'Microbacteriaceae',  # v_pho specific
    'Enterobacteriaceae',  # v_pho specific
    'Nosematidae' # v_pho specific
]

# %%
if not os.path.exists(h2_path):
    os.makedirs(h2_path)

write_pheno_file(gcta_df, h2_name, phenotype)
write_covar_file(gcta_df, h2_name, phenotype, fixed_covar, tax_covar)
write_qcovar_file(gcta_df, h2_name, phenotype, fixed_qcovar, tax_qcovar)

# %%
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:42:04 CET on Tue Jan 06 2026.
# Hostname: node07
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/GRM/hom_pop
# --pheno /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.phen
# --covar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.qcovar
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/GRM/hom_pop.grm.id].
# 1442 IDs are read from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/GRM/hom_pop.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/GRM/hom_pop.grm.bin].
# GRM for 1442 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/GRM/hom_pop.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.phen].
# Non-missing phenotypes of 1442 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.qcovar].
# 11 quantitative covariate(s) of 1442 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.covar].
# 11 discrete covariate(s) of 1442 individuals are included from [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.covar].
#
# 11 quantitative variable(s) included as covariate(s).
# 11 discrete variable(s) included as covariate(s).
# 1442 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 1442 observations, 171 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.11729  1.0341
# logL: -1100.61
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-1057.62	0.76511	1.05891
# 2	-1038.89	0.62594	1.04975
# 3	-1032.44	0.55394	1.03941
# 4	-1029.85	0.51186	1.03160
# 5	-1028.74	0.48554	1.02623
# 6	-1028.25	0.46839	1.02267
# 7	-1028.03	0.43207	1.01538
# 8	-1027.84	0.43123	1.01677
# 9	-1027.84	0.43112	1.01685
# 10	-1027.84	0.43111	1.01686
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.49274
# logL: -1149.54615
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-1038.62	1.43974
# 2	-1036.68	1.40659
# 3	-1035.83	1.38518
# 4	-1035.46	1.34056
# 5	-1035.14	1.34195
# 6	-1035.14	1.34196
# 7	-1035.14	1.34196
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.431106	0.158422
# V(e)	1.016856	0.116236
# Vp	1.447962	0.075165
# V(G)/Vp	0.297733	0.098801
#
# Sampling variance/covariance of the estimates of variance components:
# 2.509737e-02	-1.647915e-02
# -1.647915e-02	1.351071e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/VAF/VAF.hsq].
#
# Analysis finished at 15:42:07 CET on Tue Jan 06 2026
# Overall computational time: 2.97 sec.

# %%
for gg in set(pheno_df['Genetic group']):
    command = ['sbatch', script_fn, dir_in, 'depth_{}.txt'.format(gg), 'count_ref_{}.txt'.format(gg), 'queen_{}'.format(gg)]
    result = subprocess.run(command, cwd=dir_in, capture_output=True, text=True)

# %%
columns = ['Colony', 'log_v_pho', 'log_v_meta', 'Apiary', 'date', 'Year', 'Day of Year']

# Varroa-Associated families
vaf_abund = [
    'Bifidobacteriaceae',
    'Lactobacillaceae',
    'Pseudomonadaceae',   
    'Debaryomycetaceae',
    'Bartonellaceae',  
    'Morganellaceae'
]
vaf_prev = [
    'Oscillospiraceae',
    'Corynebacteriaceae',
    'Cannabaceae',
    'Aeromonadaceae',
    'Weeksellaceae',
    'Araliaceae',
    'Actinomycetaceae',
    'Trypanosomatidae'
]

fn = '{}tlf/Core_Family_LRA.csv'.format(working_path)
abund_df = pd.read_csv(fn) #, index_col='Colony').reset_index

# %%
gcta_pheno_df = pd.DataFrame(
    {
        '0' : [0] * len(bs_ids),
        # '0': bs_ids,
        'Colony': bs_ids
    }
)
gcta_pheno_df = gcta_pheno_df.merge(pheno_df[columns], on='Colony', how='left')
gcta_pheno_df = gcta_pheno_df.merge(abund_df[['Colony'] + vaf_abund + vaf_prev], on='Colony', how='left')

# replace abundance values by presence-absence for prevalence associations
lod = np.log(5e-06)
gcta_pheno_df[gcta_pheno_df[vaf_prev] >= lod] = int(1)
gcta_pheno_df[gcta_pheno_df[vaf_prev] < lod] = int(0)

gcta_pheno_df = gcta_pheno_df.fillna('NA')

# %%
gcta_pheno_df
# Out:
#       0     Colony log_v_pho  log_v_meta  Apiary        date  Year  \
# 0     0  BS16_0060 -1.987004  -15.168735    88.0  06/07/2016  2016
# 1     0  BS16_0061 -1.312186  -12.003170    88.0  06/07/2016  2016
# 2     0  BS16_0162  1.828127   -9.786422    88.0  31/08/2016  2016
# 3     0  BS16_0163 -0.619039  -15.168735    88.0  31/08/2016  2016
# 4     0  BS16_0164  0.741937  -10.537386    88.0  31/08/2016  2016
# ...  ..        ...       ...         ...     ...         ...   ...
# 1437  0  BS17_0506 -1.221672  -11.682297   128.0  01/08/2017  2017
# 1438  0  BS17_0511 -1.987004  -14.661200   128.0  01/08/2017  2017
# 1439  0  BS17_0512 -1.987004  -15.168735    97.0  01/08/2017  2017
# 1440  0  BS17_0513 -1.987004  -10.623075    97.0  01/08/2017  2017
# 1441  0  BS17_0517  0.223144  -11.524928    97.0  01/08/2017  2017
#
#       Day of Year  Bifidobacteriaceae  Lactobacillaceae  ...  Bartonellaceae  \
# 0             188           -6.146180         -4.997377  ...       -6.744082
# 1             188           -6.114353         -4.710165  ...       -6.098915
# 2             244           -5.950136         -4.598848  ...       -7.069882
# 3             244           -5.707229         -4.439819  ...       -6.104517
# 4             244           -5.405451         -4.150527  ...       -7.050514
# ...           ...                 ...               ...  ...             ...
# 1437          213           -5.955760         -4.546061  ...       -7.303314
# 1438          213           -5.556695         -3.947906  ...       -5.801414
# 1439          213           -5.081466         -4.056083  ...       -9.312203
# 1440          213           -5.038656         -4.301295  ...       -7.182466
# 1441          213           -6.144559         -4.356450  ...       -8.342813
#
#       Morganellaceae  Oscillospiraceae  Corynebacteriaceae  Cannabaceae  \
# 0          -9.018644               0.0                 0.0          0.0
# 1         -10.080948               0.0                 0.0          0.0
# 2          -7.210088               0.0                 0.0          1.0
# 3         -10.880938               0.0                 1.0          0.0
# 4          -9.954003               0.0                 0.0          1.0
# ...              ...               ...                 ...          ...
# 1437       -5.188458               0.0                 0.0          0.0
# 1438       -8.585859               0.0                 0.0          0.0
# 1439       -9.878038               0.0                 1.0          1.0
# 1440       -4.987978               0.0                 1.0          0.0
# 1441       -5.329028               0.0                 0.0          1.0
#
#       Aeromonadaceae  Weeksellaceae  Araliaceae  Actinomycetaceae  \
# 0                1.0            1.0         1.0               0.0
# 1                1.0            1.0         1.0               0.0
# 2                0.0            1.0         1.0               0.0
# 3                1.0            1.0         1.0               0.0
# 4                0.0            1.0         0.0               0.0
# ...              ...            ...         ...               ...
# 1437             0.0            1.0         0.0               1.0
# 1438             0.0            1.0         0.0               1.0
# 1439             0.0            1.0         0.0               0.0
# 1440             1.0            1.0         0.0               1.0
# 1441             0.0            1.0         0.0               0.0
#
#       Trypanosomatidae
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  0.0
# 4                  0.0
# ...                ...
# 1437               0.0
# 1438               1.0
# 1439               0.0
# 1440               0.0
# 1441               0.0
#
# [1442 rows x 22 columns]

# %%
# phenotypes
fn = '{}{}.v_pho'.format(out_path, prefix)
gcta_pheno_df[['0', 'Colony', 'log_v_pho']].to_csv(fn, header=None, sep='\t', index=False)

fn = '{}{}.v_meta'.format(out_path, prefix)
gcta_pheno_df[['0', 'Colony', 'log_v_meta']].to_csv(fn, header=None, sep='\t', index=False)

pd.read_table(fn, header=None)
# Out:
#       0          1          2
# 0     0  BS16_0060 -15.168735
# 1     0  BS16_0061 -12.003170
# 2     0  BS16_0162  -9.786422
# 3     0  BS16_0163 -15.168735
# 4     0  BS16_0164 -10.537386
# ...  ..        ...        ...
# 1437  0  BS17_0506 -11.682297
# 1438  0  BS17_0511 -14.661200
# 1439  0  BS17_0512 -15.168735
# 1440  0  BS17_0513 -10.623075
# 1441  0  BS17_0517 -11.524928
#
# [1442 rows x 3 columns]

# %%
# categorical covariable
fn = '{}{}.covar'.format(out_path, prefix)
gcta_pheno_df[['0', 'Colony', 'Apiary']].to_csv(fn, header=None, sep='\t', index=False)
# gcta_pheno_df[['0', 'Colony', 'Apiary', 'Year'] + vaf_prev].to_csv(fn, header=None, sep='\t', index=False)
# gcta_pheno_df[['0', 'Colony'] + vaf_prev].to_csv(fn, header=None, sep='\t', index=False)
# gcta_pheno_df[['0', 'Colony', 'Apiary']].to_csv(fn, header=None, sep='\t', index=False)
pd.read_table(fn, header=None)
# Out:
#       0          1      2
# 0     0  BS16_0060   88.0
# 1     0  BS16_0061   88.0
# 2     0  BS16_0162   88.0
# 3     0  BS16_0163   88.0
# 4     0  BS16_0164   88.0
# ...  ..        ...    ...
# 1437  0  BS17_0506  128.0
# 1438  0  BS17_0511  128.0
# 1439  0  BS17_0512   97.0
# 1440  0  BS17_0513   97.0
# 1441  0  BS17_0517   97.0
#
# [1442 rows x 3 columns]

# %%
# continuous covariable
fn = '{}{}.qcovar'.format(out_path, prefix)
gcta_pheno_df[['0', 'Colony', 'Day of Year']].to_csv(fn, header=None, sep='\t', index=False)
# gcta_pheno_df[['0', 'Colony', 'Day of Year'] + vaf_abund].to_csv(fn, header=None, sep='\t', index=False)
#gcta_pheno_df[['0', 'Colony'] + vaf_abund].to_csv(fn, header=None, sep='\t', index=False)
pd.read_table(fn, header=None)
# Out:
#       0          1    2
# 0     0  BS16_0060  188
# 1     0  BS16_0061  188
# 2     0  BS16_0162  244
# 3     0  BS16_0163  244
# 4     0  BS16_0164  244
# ...  ..        ...  ...
# 1437  0  BS17_0506  213
# 1438  0  BS17_0511  213
# 1439  0  BS17_0512  213
# 1440  0  BS17_0513  213
# 1441  0  BS17_0517  213
#
# [1442 rows x 3 columns]

# %% [markdown]
# # Old

# %% [markdown]
# ### .bim_like

# %% [markdown]
# I need to create bim-like files but be careful they are overwritten with make-bed command
#
# 1. Chromosome code
# 2. Variant ID
# 3. Position in centimorgans (safe to use dummy value of '0')
# 4. Base-pair coordinate (1-based; limited to 231-2)
# 5. ALT ('A1' in PLINK 1.x) allele code
# 6. REF ('A2' in PLINK 1.x) allele code

# %%
# %%time
with open('{}count_mat.pkl'.format(allele_count_path), 'rb') as inf:
    count_mat = pkl.load(inf)
print(count_mat.nbytes/1000000000)
# Out:
# 81.028587136
# CPU times: user 0 ns, sys: 1min 33s, total: 1min 33s
# Wall time: 1min 52s

# %%
f_snp_nr = 6764372
snp_nr = 7023976
assert snp_nr == count_mat.shape[0]

# %%
# %%time
# load original SNP ids
chr_ids = [''] * snp_nr
snp_pos = [''] * snp_nr
with open('{}data/gwas/BS17_0071.count'.format(working_path), 'r') as inf:
    print(inf.readline())
    i = 0
    for l in tqdm(inf):
        ch = l.split()[0]
        pos = l.split()[1]
        chr_ids[i] = ch
        snp_pos[i] = pos
        i += 1
# Out:
# CHROM POS REF ALT BS17-0071
# 7023976it [00:05, 1403874.48it/s]
# CPU times: user 4.31 s, sys: 685 ms, total: 5 s
# Wall time: 5.08 s

# %%
# %%time
# load filtered SNPs
f_chr_ids = [''] * f_snp_nr
f_snp_pos = [''] * f_snp_nr
with open('{}filtered_snps.txt'.format(allele_count_path), 'r') as inf:
    inf.readline()
    i = 0
    for l in tqdm(inf):
        ch = l.split()[0]
        pos = l.split()[1]
        f_chr_ids[i] = ch
        f_snp_pos[i] = pos
        i += 1
assert f_snp_nr == i
# Out:
# 6764372it [00:04, 1543827.37it/s]
# CPU times: user 3.7 s, sys: 676 ms, total: 4.37 s
# Wall time: 4.45 s

# %%
plink_path = '{}data/queen_genotypes/hom_pop/'.format(working_path)
bim = pd.read_csv('{}{}.bim'.format(plink_path, 'queen'), sep='\t', header=None)

# %%
# good
bim[3].to_list() == [int(x) for x in f_snp_pos]
# Out:
# True

# %%
# get back mask by comparing original snps and filtered snps. TO DO: if rerun filtering, include this part directly
snp_ids = ['{}_{}'.format(x, snp_pos[i]) for i, x in enumerate(chr_ids)]
f_snp_ids = ['{}_{}'.format(x, f_snp_pos[i]) for i, x in enumerate(f_chr_ids)]

assert len(snp_ids) == len(set(snp_ids))
assert len(f_snp_ids) == len(set(f_snp_ids))

snp_mask = ~np.isin(np.array(snp_ids), np.array(f_snp_ids))

assert np.sum(~snp_mask) == f_snp_nr

# %%
# find reference and alternative allele per SNP (REF: the one with the most counts. not sure if correct but probably REF and ALT are interchangeable) 
jj2allele = np.array(['A', 'T', 'C', 'G'])
ref_alt = np.full((snp_nr, 2), '.')
for i in tqdm(np.argwhere(~snp_mask).flatten()):
    ref_alt[i] = jj2allele[np.argsort(np.sum(count_mat[i, :, :], axis=0))[::-1][:2]]
# Out:
# 100%|██████████| 6764372/6764372 [03:30<00:00, 32146.91it/s]

# %%
bim_like = pd.DataFrame({
    'CHR': f_chr_ids,
    'SNP_ID': f_snp_ids,
    'GEN_DIST': ['0'] * f_snp_nr,
    'BP_POS': f_snp_pos,
    'ALT': ref_alt[~snp_mask][:, 1],
    'REF': ref_alt[~snp_mask][:, 0]
})

# %%
# recode snp id
chr2int = dict(zip(list(dict.fromkeys(bim_like['CHR'])), range(1, 1 + len(set(bim_like['CHR'])))))
bim_like['CHR'] = bim_like['CHR'].replace(chr2int)

def recode_SNP_ids(old_id):
    chrom, pos = old_id.split('.1_')
    return '{}:{}'.format(chr2int['{}.1'.format(chrom)], pos)

bim_like['SNP_ID'] = bim_like['SNP_ID'].map(recode_SNP_ids)
# Out:
# /tmp/ipykernel_3354437/2140746017.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bim_like['CHR'] = bim_like['CHR'].replace(chr2int)

# %%
bim_like
# Out:
#          CHR      SNP_ID GEN_DIST   BP_POS ALT REF
# 0          1      1:5671        0     5671   G   T
# 1          1      1:5698        0     5698   C   T
# 2          1      1:6621        0     6621   G   A
# 3          1      1:6717        0     6717   T   C
# 4          1      1:6823        0     6823   C   G
# ...      ...         ...      ...      ...  ..  ..
# 6764367   16  16:7225908        0  7225908   C   T
# 6764368   16  16:7225911        0  7225911   T   C
# 6764369   16  16:7226186        0  7226186   A   G
# 6764370   16  16:7226346        0  7226346   A   G
# 6764371   16  16:7227034        0  7227034   A   G
#
# [6764372 rows x 6 columns]

# %%
# good
bim[1].to_list() == bim_like['SNP_ID'].to_list()
# Out:
# True

# %%
# %%time
bim_like.to_csv('{}queen.bim_like'.format(hom_pop_path), header=False, index=False, sep='\t')
# Out:
# CPU times: user 6.47 s, sys: 509 ms, total: 6.98 s
# Wall time: 7.11 s

# %%
hom_pop_path
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/'
