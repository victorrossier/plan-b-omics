# %%
import os
import numpy as np
from tqdm import tqdm as tqdm
import pandas as pd
import bz2
import subprocess
import pickle as pkl
from itertools import chain, product
from glob import glob
from collections import defaultdict
from IPython.display import HTML
import seaborn as sns
import matplotlib.pyplot as plt

# %%
shared_data_path = '/cluster/raid/home/f80878961/data/'
script_path = "/cluster/raid/home/f80878961/scripts/tmp_scripts/"

working_path = '/cluster/raid/home/f80878961/beestrong/'
tlf_path = '{}tlf/'.format(working_path)

metadata_path = '{}00_metadata/'.format(working_path)
metadata_fn = '{}2026_BeeStrong_metadata.csv'.format(metadata_path)

# %%
# bs_ids = pheno_df['Colony'].to_list()
# snp_nr = 7023976 # will need sanity check here

# %% [markdown]
# ## Queen Genotyping Settings

# %%
count_path = '{}data/allele_freqs/sync_files/'.format(working_path) # path to the sync files available from Sonia paper

snp_nr = 7023976 # wc -l BS17_0071.count -1

prefix = 'All'
if prefix == 'All':
    pheno_df = pd.read_table('/cluster/raid/home/f80878961/beestrong/data/metadata/whole_beestrong_data.csv').rename(
        columns={
            'num_bs':'Colony',
            'group':'Genetic group'
        })
else: 
    pheno_df = pd.read_csv('{}BeeStrong_metadata.csv'.format(tlf_path))

filtered_count_path = '{}data/allele_freqs/{}/'.format(working_path, prefix)
queen_geno_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)

bs_ids = sorted([x.split('/')[-1].split('.')[0] for x in glob('{}*.count.bz2'.format(count_path))])

chunk_size = 101 # 15 chunks
batch_file = '{}bsid_batch.txt'.format(filtered_count_path)

# bs_ids = pheno_df['Colony'].to_list()
print(len(set(bs_ids).intersection(pheno_df['Colony'].to_list())))
print(len(bs_ids))
assert pheno_df['Colony'].to_list() == bs_ids

# for SNP filtering
min_prev = 0.1 # prevalence threshold for common alleles (if >2 common allele, then real tri-allelic)
min_depth = 10 # both mean and median depth 
max_depth = 50
# Out:
# 1513
# 1513

# %% [markdown]
# ## Merge allele frequencies .sync files

# %% [markdown]
# ### Write per-allele count matrices (SNP x colony for A, T, C, G)

# %%
def write_merge_sync_script(script_fn, array_str):
    runstr="""#!/bin/bash -l
#SBATCH --array=ARRAY_STRING
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --mem=20g
#SBATCH --time=4:00:00
#SBATCH --job-name=merge_sync
#SBATCH --output=%x_%A_%a.out
#SBATCH --error=%x_%A_%a.err

modulesld
ebld
module use /software/anaconda3/envs/eb/easybuild/modules/all
conda activate planb

# file listing batches of BeeStrong ids (bs_id) for parallel computing
batch_file=$1
snp_nr=$2
count_path=$3
out_path=$4

batch_id=$SLURM_ARRAY_TASK_ID

# getting bs_ids
bs_ids=$(sed -n ${batch_id}'{p;q}' ${batch_file})

python ~/scripts/plan-b-omics/bin/merge_sync.py --batch_id ${batch_id} --snp_nr ${snp_nr} --bs_ids ${bs_ids} --count_path ${count_path} --out_path ${out_path}

echo DONE""".replace("ARRAY_STRING", array_str)
    with open(script_fn, 'w') as outf:
        outf.write(runstr)

# %%
# create batch file for first time
with open(batch_file, "w") as outf:
    for i in range(0, len(bs_ids), chunk_size):
        chunk = bs_ids[i:i+chunk_size]
        outf.write(",".join(chunk) + "\n")

# %%
array_str = '1-15'
script_fn = '{}merge_sync.run'.format(script_path)
write_merge_sync_script(script_fn, array_str)

# %%
# %%bash -s "$script_fn" "$batch_file" "$snp_nr" "$count_path" "$filtered_count_path"
# cd $5
# sbatch $1 $2 $3 $4 $5
# Out:
# Submitted batch job 1388883

# %% [markdown]
# ### Merge into 3-D matrix

# %%
with open(batch_file, "r") as inf:
    batch_bs_ids = [x.rstrip().split(',') for x in inf.readlines()]
assert sum([x == bs_ids[i] for i, x in enumerate(list(chain(*batch_bs_ids)))]) == len(bs_ids)

# %%
# %%time
allele2jj = {'A': 0, 'T': 1, 'C':2, 'G':3}
count_mat = np.zeros((snp_nr, len(bs_ids), len(allele2jj)), dtype=np.uint16)

for allele, jj in allele2jj.items():
    print(allele, jj)
    
    for j, b_bs_ids in enumerate(batch_bs_ids):
        batch_id = j + 1
        batch_size = len(b_bs_ids)
        with open('{}count_{}_{}.txt'.format(filtered_count_path, allele, batch_id), 'r') as inf:
            i = 0
            for l in tqdm(inf):                    
                count_mat[i, j * chunk_size : j * chunk_size + batch_size, jj] = np.array(l.split()[2:], dtype=np.int16)
                i += 1
# Out:
# A 0
# 7023976it [01:27, 79911.85it/s]
# 7023976it [01:12, 96871.43it/s]
# 7023976it [01:13, 95607.20it/s]
# 7023976it [01:12, 96395.80it/s]
# 7023976it [01:13, 95634.25it/s]
# 7023976it [01:13, 95841.95it/s]
# 7023976it [01:12, 96750.18it/s]
# 7023976it [01:13, 96216.97it/s]
# 7023976it [01:13, 96170.55it/s]
# 7023976it [01:13, 94955.64it/s]
# 7023976it [01:10, 99338.00it/s]
# 7023976it [01:10, 100071.38it/s]
# 7023976it [01:10, 99098.12it/s]
# 7023976it [01:20, 86892.53it/s]
# 7023976it [01:19, 88464.59it/s]
# T 1
# 7023976it [01:20, 87638.04it/s]
# 7023976it [01:19, 88887.25it/s]
# 7023976it [01:20, 87229.69it/s]
# 7023976it [01:21, 86617.28it/s]
# 7023976it [01:21, 86346.12it/s]
# 7023976it [01:20, 87418.80it/s]
# 7023976it [01:20, 87219.67it/s]
# 7023976it [01:22, 85541.27it/s]
# 7023976it [01:22, 85528.61it/s]
# 7023976it [01:22, 85412.89it/s]
# 7023976it [01:21, 86602.88it/s]
# 7023976it [01:21, 86004.87it/s]
# 7023976it [01:20, 86980.82it/s]
# 7023976it [01:21, 86634.61it/s]
# 7023976it [01:19, 87840.42it/s]
# C 2
# 7023976it [01:22, 85362.98it/s]
# 7023976it [01:21, 86695.99it/s]
# 7023976it [01:21, 86272.75it/s]
# 7023976it [01:21, 85767.50it/s]
# 7023976it [01:23, 83933.48it/s]
# 7023976it [01:21, 85708.65it/s]
# 7023976it [01:22, 85253.64it/s]
# 7023976it [01:22, 84884.01it/s]
# 7023976it [01:23, 84503.23it/s]
# 7023976it [01:23, 84575.33it/s]
# 7023976it [01:23, 84403.22it/s]
# 7023976it [01:22, 85003.84it/s]
# 7023976it [01:22, 84759.25it/s]
# 7023976it [01:23, 84321.06it/s]
# 7023976it [01:21, 86137.15it/s]
# G 3
# 7023976it [01:21, 86597.14it/s]
# 7023976it [01:21, 86523.52it/s]
# 7023976it [01:23, 84421.79it/s]
# 7023976it [01:21, 85817.88it/s]
# 7023976it [01:22, 85413.62it/s]
# 7023976it [01:22, 85604.58it/s]
# 7023976it [01:22, 85174.04it/s]
# 7023976it [01:23, 84585.02it/s]
# 7023976it [01:24, 83101.66it/s]
# 7023976it [01:22, 84669.79it/s]
# 7023976it [01:22, 84762.85it/s]
# 7023976it [01:22, 85111.30it/s]
# 7023976it [01:21, 86124.85it/s]
# 7023976it [01:22, 85098.11it/s]
# 7023976it [01:20, 86877.37it/s]
# CPU times: user 1h 9min 1s, sys: 10min 24s, total: 1h 19min 25s
# Wall time: 1h 20min 4s

# %%
# %%time
with open('{}count_mat.pkl'.format(filtered_count_path), 'wb') as outf:
    pkl.dump(count_mat, outf, protocol=pkl.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 909 ms, sys: 2min 15s, total: 2min 16s
# Wall time: 2min 33s

# %% [markdown]
# ## Filter SNPs and recode alleles

# %% [markdown]
# filtering
# 1. monoallelic filtering : 3/4 tables empty
# 2. mitochondrial SNP: contig NC_001566.1
# 3. tri-allelic SNP filtering: >2 allele present in min. 10% colonies, else delete variants from third and fourth alleles
# 4. min-max depth (10/50, on mean AND median) (after tri-allelic variants deletions, also not including N and deletions)

# %%
# %%time
with open('{}count_mat.pkl'.format(filtered_count_path), 'rb') as inf:
    count_mat = pkl.load(inf)
print(count_mat.nbytes/1000000000)
# Out:
# 85.018205504
# CPU times: user 0 ns, sys: 1min 10s, total: 1min 10s
# Wall time: 1min 26s

# %%
with open(batch_file, "r") as inf:
    batch_bs_ids = [x.rstrip().split(',') for x in inf.readlines()]
assert sum([x == bs_ids[i] for i, x in enumerate(list(chain(*batch_bs_ids)))]) == len(bs_ids)

# %%
batch_i = 0
batch_ii = len(bs_ids)
print(batch_ii)
# Out:
# 1513

# %%
# %%time
# counts the number of A, T, C, G allele per SNP # should take 7min
allele_prev = np.sum(count_mat[:, batch_i:batch_ii, :] > 0, axis=1)
allele_prev
# Out:
# CPU times: user 2min 44s, sys: 5.78 s, total: 2min 50s
# Wall time: 2min 51s
# array([[   1, 1513,    3,    9],
#        [   4, 1513,   27,    2],
#        [1513,   11,    2,   22],
#        ...,
#        [1437,  849,  118,  337],
#        [ 397, 1364, 1058,  218],
#        [ 335, 1504,  310,  170]])

# %%
# %%time
# if count 3/4 alleles == 0, then monoallelic
mono_mask = np.sum(allele_prev > 0, axis=1) == 1
print(np.sum(mono_mask))

# tri-allelic stringent
tri_stringent_mask = np.sum(allele_prev > 0, axis=1) > 2
print(np.sum(tri_stringent_mask))

# tri-allelic relaxed (filter SNP only when >2 common alleles, i.e., an allele present in >= 10% of colonies)
tri_mask = np.sum(allele_prev >= ((batch_ii - batch_i) * min_prev), axis=1) > 2
print(np.sum(tri_mask))
# Out:
# 3261
# 6963287
# 17207
# CPU times: user 433 ms, sys: 41.7 ms, total: 475 ms
# Wall time: 479 ms

# %%
# iterate through stringent tri-allelic SNPs: filter if ambigous else recode (delete 3rd and fourth)
ambi_mask = np.full(snp_nr, False)
for i in tqdm(np.argwhere(tri_stringent_mask).flatten()):

    # get number of alleles and sort by prevalence 
    atcg_prev = allele_prev[i, :]
    alleles_sorted_by_prevalence = np.argsort(atcg_prev)

    # if 2nd and 3rd alleles are equally common --> ambiguous --> filter
    if atcg_prev[alleles_sorted_by_prevalence[1]] == atcg_prev[alleles_sorted_by_prevalence[2]]:
        ambi_mask[i] = True

    # else delete 3rd and 4rth alleles
    else:
        count_mat[i, batch_i:batch_ii, alleles_sorted_by_prevalence[:2]] = 0

np.sum(ambi_mask)
# Out:
# 100%|██████████| 6963287/6963287 [00:50<00:00, 138304.88it/s]
# 122115

# %%
# %%time
# depth filtering --> if to, long I could consider iterating ...to have an overview of the time it takes # 8 min
depth  = np.sum(count_mat[:, batch_i:batch_ii, :], axis = 2)
# Out:
# CPU times: user 2min 23s, sys: 58 s, total: 3min 21s
# Wall time: 3min 22s

# %%
# %%time
mean_depth = np.mean(depth, axis = 1)
median_depth = np.full(snp_nr, -1) # np.median breaks the kernel somehow
for i in tqdm(range(snp_nr)):
    median_depth[i] =  np.median(depth[i])

depth_mask = (mean_depth < min_depth) | (mean_depth > max_depth) | (median_depth < min_depth) | (median_depth > max_depth) 
np.sum(depth_mask)
# Out:
# 100%|██████████| 7023976/7023976 [02:47<00:00, 41860.60it/s]
# CPU times: user 3min 4s, sys: 686 ms, total: 3min 5s
# Wall time: 3min 7s
# 123823

# %%
# %%time
chr_ids = [''] * snp_nr
snp_pos = [''] * snp_nr
mito_mask = np.full(snp_nr, False)
with open('{}count_A_1.txt'.format(filtered_count_path), 'r') as inf:
    i = 0
    for l in tqdm(inf):
        ch = l.split()[0]
        pos = l.split()[1]
        chr_ids[i] = ch
        snp_pos[i] = pos
        if ch == 'NC_001566.1':
            mito_mask[i] = True
        i += 1
np.sum(mito_mask)
# Out:
# 7023976it [00:25, 272771.65it/s]
# CPU times: user 23.4 s, sys: 2.03 s, total: 25.4 s
# Wall time: 25.8 s
# 287

# %%
# combine masks
mask = mono_mask + tri_mask + depth_mask + mito_mask + ambi_mask
print(np.sum(mask))
print(snp_nr - np.sum(mask))
# Out:
# 257718
# 6766258

# %% [markdown]
# ### Write PLINK bim_like files

# %% [markdown]
# 1. Chromosome code
# 2. Variant ID
# 3. Position in centimorgans (safe to use dummy value of '0')
# 4. Base-pair coordinate (1-based; limited to 231-2)
# 5. ALT ('A1' in PLINK 1.x) allele code
# 6. REF ('A2' in PLINK 1.x) allele code

# %%
# find reference and alternative allele per SNP (REF: the one with the most counts)
jj2allele = np.array(['A', 'T', 'C', 'G'])
ref_alt = np.full((snp_nr, 2), '.')
for i in tqdm(np.argwhere(~mask).flatten()):
    ref_alt[i] = jj2allele[np.argsort(np.sum(count_mat[i, :, :], axis=0))[::-1][:2]]
# Out:
# 100%|██████████| 6766258/6766258 [03:38<00:00, 30928.81it/s]

# %%
bim_like = pd.DataFrame({
    'CHROM': np.array(chr_ids)[~mask],
    'SNP_ID': np.array(snp_pos)[~mask],
    'GEN_DIST': ['0'] * np.sum(~mask),
    'POS': np.array(snp_pos)[~mask],
    'ALT': ref_alt[~mask][:, 1],
    'REF': ref_alt[~mask][:, 0]
})

# recode chromosome and SNP identifiers into integers
chr2int = dict(zip(list(dict.fromkeys(bim_like['CHROM'])), range(1, 1 + len(set(bim_like['CHROM'])))))
bim_like['CHROM'] = bim_like['CHROM'].replace(chr2int)

bim_like['CHROM'] = bim_like['CHROM'].astype(str)
bim_like['GEN_DIST'] = bim_like['GEN_DIST'].astype(str)
bim_like['SNP_ID'] = bim_like[["CHROM", "POS"]].agg(":".join, axis=1)
# Out:
# /tmp/ipykernel_2652648/1469035007.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bim_like['CHROM'] = bim_like['CHROM'].replace(chr2int)

# %%
bim_like
# Out:
#         CHROM      SNP_ID GEN_DIST      POS ALT REF
# 0           1      1:5671        0     5671   G   T
# 1           1      1:5698        0     5698   C   T
# 2           1      1:6621        0     6621   G   A
# 3           1      1:6717        0     6717   A   C
# 4           1      1:6823        0     6823   C   G
# ...       ...         ...      ...      ...  ..  ..
# 6766253    16  16:7225908        0  7225908   C   T
# 6766254    16  16:7225911        0  7225911   T   C
# 6766255    16  16:7226186        0  7226186   A   G
# 6766256    16  16:7226346        0  7226346   A   G
# 6766257    16  16:7227034        0  7227034   A   G
#
# [6766258 rows x 6 columns]

# %%
# %%time
bim_like.to_csv('{}{}.bim_like'.format(queen_geno_path, prefix), header=False, index=False, sep='\t')
# Out:
# CPU times: user 6.17 s, sys: 395 ms, total: 6.57 s
# Wall time: 6.73 s

# %% [markdown]
# ### Export count_ref.txt and depth.txt files

# %%
# TO DO: insert also alleles! --> aim to have same .bgs as Sonia!
# ,CHROM,POS,REF,ALT,BS16_0032...

# %%
# %%time
# creating depth dataframe # 30min...
depth_df = pd.DataFrame(depth[~mask])
# Out:
# CPU times: user 8.46 s, sys: 15.3 s, total: 23.8 s
# Wall time: 23.9 s

# %%
depth_df.insert(0, 'CHROM',  bim_like['CHROM'])
depth_df.insert(1, 'POS', bim_like['POS'])
depth_df.insert(2, 'REF',  bim_like['REF'])
depth_df.insert(3, 'ALT', bim_like['ALT'])
depth_df.columns = ['CHROM', 'POS', 'REF', 'ALT'] + bs_ids[batch_i: batch_ii]

# %%
# %%time
for gg in set(pheno_df['Genetic group']):
    print(gg)
    depth_df[['CHROM', 'POS', 'REF', 'ALT'] + list(pheno_df[pheno_df['Genetic group'] == gg]['Colony'])].to_csv('{}depth_{}.txt'.format(queen_geno_path, gg), header=True, index=False, sep='\t')
# Out:
# Caucasica
# hybrid
# Mellifera
# Ligustica_Carnica
# CPU times: user 23min 46s, sys: 2min 26s, total: 26min 13s
# Wall time: 26min 31s

# %%
# %%time
# getting the ref allele counts 5-8min...
count_ref  = np.max(count_mat[:, batch_i:batch_ii, :], axis = 2)

# creating reference allele count dataframe
count_ref_df = pd.DataFrame(count_ref[~mask])
count_ref_df.insert(0, 'CHROM',  bim_like['CHROM'])
count_ref_df.insert(1, 'POS', bim_like['POS'])
count_ref_df.insert(2, 'REF',  bim_like['REF'])
count_ref_df.insert(3, 'ALT', bim_like['ALT'])
count_ref_df.columns = ['CHROM', 'POS', 'REF', 'ALT'] + bs_ids[batch_i: batch_ii]
# Out:
# CPU times: user 4min 58s, sys: 4min 6s, total: 9min 4s
# Wall time: 9min 5s

# %%
# %%time
for gg in set(pheno_df['Genetic group']):
    print(gg)
    count_ref_df[['CHROM', 'POS', 'REF', 'ALT'] + list(pheno_df[pheno_df['Genetic group'] == gg]['Colony'])].to_csv('{}count_ref_{}.txt'.format(queen_geno_path, gg), header=True, index=False, sep='\t')
# Out:
# Caucasica
# hybrid
# Mellifera
# Ligustica_Carnica
# CPU times: user 22min 17s, sys: 1min 5s, total: 23min 22s
# Wall time: 23min 39s

# %% [markdown]
# ## Queen genotype reconstruction

# %%
def write_run_beethoven_script(script_fn):
    runstr="""#!/bin/bash -l
#SBATCH --cpus-per-task=10
#SBATCH --mem=40g
#SBATCH --time=48:00:00
#SBATCH --job-name=beethoven
#SBATCH --output=%x_%j.out
#SBATCH --error=%x_%j.err

modulesld
ebld
module use /software/anaconda3/envs/eb/easybuild/modules/all
conda activate planb

dir_in=$1
depth_file=$2
count_ref_file=$3
prefix=$4

genoqueen_hom ${dir_in} ${depth_file} ${count_ref_file} 4 10 ${prefix} 1000

echo DONE"""
    with open(script_fn, 'w') as outf:
        outf.write(runstr)

# %%
script_fn = '{}beethoven.run'.format(script_path)
write_run_beethoven_script(script_fn)

# %%
script_fn
# Out:
# '/cluster/raid/home/f80878961/scripts/tmp_scripts/beethoven.run'

# %%
gg = 'Caucasica'
command = ['sbatch', script_fn, queen_geno_path, 'depth_{}.txt'.format(gg), 'count_ref_{}.txt'.format(gg), '{}_{}'.format(prefix, gg)]
result = subprocess.run(command, cwd=queen_geno_path, capture_output=True, text=True)

# %%
for gg in set(pheno_df['Genetic group']):
    if gg == 'Caucasica':
        continue
    print(gg)
    command = ['sbatch', script_fn, queen_geno_path, 'depth_{}.txt'.format(gg), 'count_ref_{}.txt'.format(gg), '{}_{}'.format(prefix, gg)]
    result = subprocess.run(command, cwd=queen_geno_path, capture_output=True, text=True)
# Out:
# hybrid
# Mellifera
# Ligustica_Carnica

# %% [markdown]
# ## Write PLINK .ped

# %% [markdown]
# ### Split beethoven .prob files

# %%
prefix = 'queen'
plink_path = '{}data/queen_genotypes/hom_pop/'.format(working_path)
populations = ['Caucasica', 'Ligustica_Carnica', 'Mellifera', 'hybrid']
chunk_size = 25
prob_threshold = 0.95

# %%
# need to split .prob files into 3: AA, AR, RR --> easier to read probability of these genotypes simulateously then...
def split_prob_file(
    plink_path, prefix, pop):

    prob_file = '{}{}_{}.prob'.format(plink_path, prefix, pop)
    aa_file = '{}{}_{}_AA.prob'.format(plink_path, prefix, pop)
    ar_file = '{}{}_{}_AR.prob'.format(plink_path, prefix, pop)
    rr_file = '{}{}_{}_RR.prob'.format(plink_path, prefix, pop)
    
    out_aa = open(aa_file, 'w')
    out_ar = open(ar_file, 'w')
    out_rr = open(rr_file, 'w')
    
    with open(prob_file, 'r') as inf:
        headers = inf.readline()
        out_aa.write(headers.rstrip(',geno\n') + '\n')
        out_ar.write(headers.rstrip(',geno\n') + '\n')
        out_rr.write(headers.rstrip(',geno\n') + '\n')

        for l in tqdm(inf):
            split_line = l.rstrip().split(',')
            geno = split_line[-1]
            if geno == 'AA':
                out_aa.write(','.join(split_line[:-1]) + '\n')
            elif geno == 'AR':
                out_ar.write(','.join(split_line[:-1]) + '\n')
            elif geno == 'RR':
                out_rr.write(','.join(split_line[:-1]) + '\n')
            else: 
                print('GENO: {}'.format(geno))
                      
    out_aa.close()
    out_ar.close()
    out_rr.close()

# %%
for pop in populations:
    split_prob_file(plink_path, prefix, pop)
# Out:
# 20293116it [00:46, 437729.20it/s]
# 20293116it [24:53, 13589.27it/s]
# 20293116it [15:02, 22474.99it/s]
# 20293116it [14:04, 24026.43it/s]

# %% [markdown]
# ### Write .ped by population with probability threshold

# %% [markdown]
# debug

# %%
def write_ped_woprob(
    plink_path, prefix, pop, chunk_bs_ids, batch_j, chunk_size):
    
    # index of column with first bs_id (skipping metadata columns)
    bgs_col_idx = 5
    
    bim_like = pd.read_csv('{}{}.bim_like'.format(plink_path, prefix), sep='\t', header=None)
    bgs_file = '{}{}_{}.bgs'.format(plink_path, prefix, pop)
    snp_nr = len(bim_like)
    
    start_j = batch_j * chunk_size
    ped_mat = np.full((len(chunk_bs_ids), 2 * snp_nr), '', dtype='U1')
    
    inf = open(bgs_file, 'r')

    # check we have the same bs ids in header than in batch
    header_bsids = inf.readline()
    assert header_bsids.rstrip().split(',')[bgs_col_idx:][start_j: start_j + len(chunk_bs_ids)] == chunk_bs_ids, 'bs_id mismatch'

    # iterate snps and colonies
    for i in tqdm(range(snp_nr)):
        ref_numbers = inf.readline().rstrip().split(',')[bgs_col_idx:]

        for j in range(start_j, start_j + len(chunk_bs_ids)):
            ref_nr = ref_numbers[j]

            # homozygote reference
            if (ref_nr == '2'):
                ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 5]
                ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 5]
            # heterozygote
            elif (ref_nr == '1'):
                ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 5]
                ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 4]
            # homozygote alternative
            elif (ref_nr == '0'):
                ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 4]
                ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 4]
            # below prob_threshold
            elif ref_nr in {'0', '1', '2'}:
                ped_mat[j - start_j, 2 * i] = '0'
                ped_mat[j - start_j, 2 * i + 1] = '0'
            else: 
                print('ERROR')
            
    inf.close()

    ped_df = pd.DataFrame({
        'FID': ['0'] * len(chunk_bs_ids), 
        'IID': chunk_bs_ids,
        'PID': ['0'] * len(chunk_bs_ids),
        'MID': ['0'] * len(chunk_bs_ids),
        'SEX': ['0'] * len(chunk_bs_ids), 
        'PHENOTYPE': ['-9'] * len(chunk_bs_ids)
    })
    ped_df = ped_df.join(pd.DataFrame(ped_mat))
    ped_df.to_csv('{}{}_{}_{}.ped'.format(plink_path, prefix, pop, batch_j), header=False, index=False, sep='\t')

# %%
queen_geno_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)
plink_path = queen_geno_path
populations = ['Ligustica_Carnica', 'Mellifera']
populations = ['Ligustica_Carnica']
prob_threshold = 0

# %%
prefix = 'Sonia_All'
plink_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)
pop = 'Ligustica_Carnica'

# %%
batch_file = '{}bsid_batch_{}.txt'.format(plink_path, pop)
with open(batch_file, "r") as inf:
    batch_bs_ids = [x.rstrip().split(',') for x in inf.readlines()]
batch_file
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/Sonia_All/bsid_batch_Ligustica_Carnica.txt'

# %%
batch_file
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/Sonia_All/bsid_batch_Ligustica_Carnica.txt'

# %%
batch_j = 0
chunk_bs_ids = batch_bs_ids[batch_j]
chunk_size = 25

# %%
bim_like
# Out:
#              0           1         2        3    4    5
# 0        CHROM      SNP_ID  GEN_DIST      POS  ALT  REF
# 1            1      1:5671         0     5671    C    T
# 2            1      1:5698         0     5698    C    T
# 3            1      1:6621         0     6621    G    A
# 4            1      1:6717         0     6717    T    C
# ...        ...         ...       ...      ...  ...  ...
# 6831070     16  16:7225911         0  7225911    T    C
# 6831071     16  16:7225986         0  7225986    C    G
# 6831072     16  16:7226186         0  7226186    C    G
# 6831073     16  16:7226346         0  7226346    A    G
# 6831074     16  16:7227034         0  7227034    A    G
#
# [6831075 rows x 6 columns]

# %%
# index of column with first bs_id (skipping metadata columns)
bgs_col_idx = 5

bim_like = pd.read_csv('{}{}.bim_like'.format(plink_path, prefix), sep='\t', header=None)
bgs_file = '{}{}_{}.bgs'.format(plink_path, prefix, pop)
snp_nr = len(bim_like)

start_j = batch_j * chunk_size
ped_mat = np.full((len(chunk_bs_ids), 2 * snp_nr), '', dtype='U1')

inf = open(bgs_file, 'r')

# check we have the same bs ids in header than in batch
header_bsids = inf.readline()
assert header_bsids.rstrip().split(',')[bgs_col_idx:][start_j: start_j + len(chunk_bs_ids)] == chunk_bs_ids, 'bs_id mismatch'
# Out:
# /tmp/ipykernel_1824108/1242175706.py:4: DtypeWarning: Columns (0,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   bim_like = pd.read_csv('{}{}.bim_like'.format(plink_path, prefix), sep='\t', header=None)

# %%
# iterate snps and colonies
for i in tqdm(range(snp_nr)):
    ref_numbers = inf.readline().rstrip().split(',')[bgs_col_idx:]

    for j in range(start_j, start_j + len(chunk_bs_ids)):
        ref_nr = ref_numbers[j]

        # homozygote reference
        if (ref_nr == '2'):
            ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 5]
            ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 5]
        # heterozygote
        elif (ref_nr == '1'):
            ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 5]
            ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 4]
        # homozygote alternative
        elif (ref_nr == '0'):
            ped_mat[j - start_j, 2 * i] = bim_like.iloc[i, 4]
            ped_mat[j - start_j, 2 * i + 1] = bim_like.iloc[i, 4]
        # below prob_threshold
        elif ref_nr in {'0', '1', '2'}:
            ped_mat[j - start_j, 2 * i] = '0'
            ped_mat[j - start_j, 2 * i + 1] = '0'
        else: 
            print('ERROR')
        
inf.close()

ped_df = pd.DataFrame({
    'FID': ['0'] * len(chunk_bs_ids), 
    'IID': chunk_bs_ids,
    'PID': ['0'] * len(chunk_bs_ids),
    'MID': ['0'] * len(chunk_bs_ids),
    'SEX': ['0'] * len(chunk_bs_ids), 
    'PHENOTYPE': ['-9'] * len(chunk_bs_ids)
})
ped_df = ped_df.join(pd.DataFrame(ped_mat))
ped_df.to_csv('{}{}_{}_{}.ped'.format(plink_path, prefix, pop, batch_j), header=False, index=False, sep='\t')

# %%
def write_write_ped_script(script_fn, array_str):
    runstr="""#!/bin/bash -l
#SBATCH --array=ARRAY_STRING
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --mem=50g
#SBATCH --time=6:00:00
#SBATCH --job-name=write_ped
#SBATCH --output=%x_%A_%a.out
#SBATCH --error=%x_%A_%a.err

modulesld
ebld
module use /software/anaconda3/envs/eb/easybuild/modules/all
conda activate planb

# file listing batches of BeeStrong ids (bs_id) for parallel computing
batch_file=$1
chunk_size=$2
plink_path=$3
prefix=$4
pop=$5
prob_threshold=$6
    
batch_id=$SLURM_ARRAY_TASK_ID

# getting bs_ids
chunk_bs_ids=$(sed -n ${batch_id}'{p;q}' ${batch_file})
    
python ~/scripts/plan-b-omics/bin/write_ped.py --chunk_bs_ids ${chunk_bs_ids} --batch_id ${batch_id} --chunk_size ${chunk_size} --plink_path ${plink_path} --prefix ${prefix} --pop ${pop} --prob_threshold ${prob_threshold}

echo DONE""".replace("ARRAY_STRING", array_str)
    with open(script_fn, 'w') as outf:
        outf.write(runstr)

# %%
queen_geno_path
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/All/'

# %%
chunk_size = 25
prefix = 'All'
populations = ['Caucasica', 'Ligustica_Carnica', 'Mellifera', 'hybrid']

# if threshold = 0, then the .prob files are not used
prob_threshold = 0

# %%
# write batch files
for pop in populations:
    batch_file = '{}bsid_batch_{}.txt'.format(plink_path, pop)
    bs_ids = pheno_df[pheno_df['Genetic group'] == pop]['Colony'].to_list()
    print(len(bs_ids))
    
    batch_bs_ids = []
    with open(batch_file, "w") as outf:
        for i in range(0, len(bs_ids), chunk_size):
            chunk = bs_ids[i:i+chunk_size]
            batch_bs_ids.append(chunk)
            outf.write(",".join(chunk) + "\n")
# Out:
# 703
# 407

# %%
### Sonia .bgs
def get_bs_ids_from_bgs(bgs_file, bgs_col_idx=5):
    with open(bgs_file, 'r') as inf:
        header_bsids = inf.readline()
    return header_bsids.rstrip().split(',')[bgs_col_idx:]

def write_bim_like_from_bgs(bgs_file, plink_path, prefix):
    '''
    basically takes the first few columns of the .bgs file to create a  bim like file (that I am using to compute ped files)
    '''
    bim_df = pd.read_csv(bgs_file, sep=',', usecols=range(5))
    bim_df['SNP_ID'] = bim_df['CHROM'].astype(str) + ':' + bim_df['POS'].astype(str)
    bim_df['GEN_DIST'] = ['0'] * len(bim_df)
    bim_df = bim_df[['CHROM', 'SNP_ID', 'GEN_DIST', 'POS', 'ALT', 'REF']]
    bim_df.to_csv('{}{}.bim_like'.format(plink_path, prefix), index=False, header=None, sep='\t')
    
chunk_size = 25

prefix = 'Sonia_All'
queen_geno_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)
plink_path = queen_geno_path
populations = ['Ligustica_Carnica', 'Mellifera']
populations = ['Ligustica_Carnica']
prob_threshold = 0

# write batch files (for Sonia)
for pop in populations:
    batch_file = '{}bsid_batch_{}.txt'.format(plink_path, pop)
    bs_ids = get_bs_ids_from_bgs('{}{}_{}.bgs'.format(plink_path, prefix, pop), bgs_col_idx=5)
    print(len(bs_ids))
    
    batch_bs_ids = []
    with open(batch_file, "w") as outf:
        for i in range(0, len(bs_ids), chunk_size):
            chunk = bs_ids[i:i+chunk_size]
            batch_bs_ids.append(chunk)
            outf.write(",".join(chunk) + "\n")
# Out:
# 821

# %%
write_bim_like_from_bgs('/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/Sonia_All/Sonia_All_Ligustica_Carnica.bgs', plink_path, prefix)

# %%
pop = 'Ligustica_Carnica'
# pop = 'Caucasica'
# pop = 'Mellifera'
# pop = 'hybrid'

batch_file = '{}bsid_batch_{}.txt'.format(plink_path, pop)
with open(batch_file, "r") as inf:
    batch_bs_ids = [x.rstrip().split(',') for x in inf.readlines()]
batch_file
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/Sonia_All/bsid_batch_Ligustica_Carnica.txt'

# %%
array_str = '1-{}'.format(len(batch_bs_ids)) if len(batch_bs_ids) > 1 else '1'
script_fn = '{}write_ped.run'.format(script_path)
write_write_ped_script(script_fn, array_str)

# %%
# %%bash -s "$script_fn" "$batch_file" "$chunk_size" "$plink_path" "$prefix" "$pop" "$prob_threshold"
# cd $4
# sbatch $1 $2 $3 $4 $5 $6 $7
# Out:
# Submitted batch job 1390200

# %% [markdown]
# cat the ped files

# %% [markdown]
# ### Write PLINK .map files

# %% [markdown]
# .map file is also needed to convert ped to bed (only map + bed)
#
# CHR   SNP_ID   GEN_DIST   BP_POS
#
# basically bim wihout REF and ALT

# %%
prefix = 'All'
prefix = 'Sonia_All'
queen_geno_path = '{}data/queen_genotypes/{}/'.format(working_path, prefix)
populations = ['Ligustica_Carnica']

# %%
bim_like = pd.read_csv('{}{}.bim_like'.format(queen_geno_path, prefix), sep='\t', header=None)

# %%
for pop in populations:
    print(pop)
    bim_like[[0, 1, 2, 3]].to_csv('{}{}_{}.map'.format(queen_geno_path, prefix, pop), header=False, index=False, sep='\t')
# Out:
# Ligustica_Carnica

# %% [markdown]
# convert to bed in CLI. Not sure how long it will take for convertion to bed...
#
# ml PLINK
#
# plink --file queen --make-bed --out queen --allow-extra-chr

# %% [markdown]
# ## GREML H2 analyses

# %%
plink_prefix = 'hom_pop'
plink_path = '{}03_queen_genotyping/queen_genotypes/{}/'.format(working_path, plink_prefix)
plink_files = '{}{}'.format(plink_path, plink_prefix)

gcta_path = '/cluster/raid/home/f80878961/bin/gcta-1.95.0-linux-kernel-3-x86_64/gcta64' # cluster version fails for GRM 
greml_path = '{}04_heritability_calculation/{}/'.format(working_path, plink_prefix)

populations = ['Mellifera', 'Ligustica_Carnica', 'hybrid']

lod = np.log(5e-06) # for symbiosphere taxa

phen2name = {'log_v_meta': 'VLmeta', 'log_v_pho':'VLcount'}

# %% [markdown]
# ### Compute GRMs

# %%
plink_prefix = 'hom_pop'
plink_files = '{}{}'.format(plink_path, plink_prefix)

pop = 'all_pops'
maf = 0.01

grm_path = '{}{}/GRM_maf{}/'.format(greml_path, pop, str(maf).replace('.', ''))
if not os.path.exists(grm_path):
    os.makedirs(grm_path)
        
grm_files = '{}{}'.format(grm_path, plink_prefix)

# %%
# %%bash -s "$grm_path" "$gcta_path" "$plink_files" "$maf" "$grm_files"
# mkdir -p $1
# cd $1
# $2 --bfile $3 --make-grm --maf $4 --out $5
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:24:25 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Options:
#
# --bfile /cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/hom_pop
# --make-grm
# --maf 0.05
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/all_pops/GRM_maf005/hom_pop
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/hom_pop.fam]...
# 1442 individuals to be included from FAM file.
# 1442 individuals to be included. 0 males, 0 females, 1442 unknown.
# Reading PLINK BIM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/hom_pop.bim]...
# 6764372 SNPs to be included from BIM file(s).
# Threshold to filter variants: MAF > 0.050000.
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-1442
#   1442 samples, 6764372 markers, 1040403 GRM elements
# IDs for the GRM file have been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/all_pops/GRM_maf005/hom_pop.grm.id]
# Computing GRM...
#   100% finished in 275.8 sec
# 6764372 SNPs have been processed.
#   Used 1801792 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/all_pops/GRM_maf005/hom_pop.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/all_pops/GRM_maf005/hom_pop.grm.N.bin]
#
# Analysis finished at 14:29:07 CET on Fri Jan 09 2026
# Overall computational time: 4 minutes 42 sec.

# %%
plink_files
# Out:
# '/cluster/raid/home/f80878961/beestrong/03_queen_genotyping/queen_genotypes/hom_pop/hom_pop'

# %%
maf = 0.01
# maf = 0.05
plink_prefix = 'queen'
for pop in populations:
    print(pop)
    plink_files = '{}{}_{}'.format(plink_path, plink_prefix, pop)
    
    grm_path = '{}{}/GRM_maf{}/'.format(greml_path, pop, str(maf).replace('.', ''))
    if not os.path.exists(grm_path):
        os.makedirs(grm_path)
    grm_files = '{}{}'.format(grm_path, plink_prefix)
    
    command = [gcta_path, '--bfile', plink_files, '--make-grm', '--maf' , str(maf), '--out', grm_files]
    result = subprocess.run(command, cwd=grm_path, capture_output=True, text=True)
    print(result.stderr)
    print(result.stdout)
# Out:
# Mellifera
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:25:05 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Options:
#
# --bfile /cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Mellifera
# --make-grm
# --maf 0.05
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Mellifera/GRM_maf005/queen
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Mellifera.fam]...
# 405 individuals to be included from FAM file.
# 405 individuals to be included. 0 males, 0 females, 405 unknown.
# Reading PLINK BIM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Mellifera.bim]...
# 6764372 SNPs to be included from BIM file(s).
# Threshold to filter variants: MAF > 0.050000.
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-405
#   405 samples, 6764372 markers, 82215 GRM elements
# IDs for the GRM file have been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Mellifera/GRM_maf005/queen.grm.id]
# Computing GRM...
#   100% finished in 26.2 sec
# 6764372 SNPs have been processed.
#   Used 1553315 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Mellifera/GRM_maf005/queen.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Mellifera/GRM_maf005/queen.grm.N.bin]
#
# Analysis finished at 15:25:38 CET on Fri Jan 09 2026
# Overall computational time: 33.04 sec.
#
# Ligustica_Carnica
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:25:38 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Options:
#
# --bfile /cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Ligustica_Carnica
# --make-grm
# --maf 0.05
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Ligustica_Carnica.fam]...
# 645 individuals to be included from FAM file.
# 645 individuals to be included. 0 males, 0 females, 645 unknown.
# Reading PLINK BIM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_Ligustica_Carnica.bim]...
# 6764372 SNPs to be included from BIM file(s).
# Threshold to filter variants: MAF > 0.050000.
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-645
#   645 samples, 6764372 markers, 208335 GRM elements
# IDs for the GRM file have been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen.grm.id]
# Computing GRM...
#   100% finished in 61.5 sec
# 6764372 SNPs have been processed.
#   Used 1718847 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/Ligustica_Carnica/GRM_maf005/queen.grm.N.bin]
#
# Analysis finished at 15:26:46 CET on Fri Jan 09 2026
# Overall computational time: 1 minute 8 sec.
#
# hybrid
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:26:46 CET on Fri Jan 09 2026.
# Hostname: node07
#
# Options:
#
# --bfile /cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_hybrid
# --make-grm
# --maf 0.05
# --out /cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_hybrid.fam]...
# 372 individuals to be included from FAM file.
# 372 individuals to be included. 0 males, 0 females, 372 unknown.
# Reading PLINK BIM file from [/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/queen_hybrid.bim]...
# 6764372 SNPs to be included from BIM file(s).
# Threshold to filter variants: MAF > 0.050000.
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-372
#   372 samples, 6764372 markers, 69378 GRM elements
# IDs for the GRM file have been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.id]
# Computing GRM...
#   100% finished in 23.8 sec
# 6764372 SNPs have been processed.
#   Used 1931679 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [/cluster/raid/home/f80878961/beestrong/data/heritability_greml/hom_pop/hybrid/GRM_maf005/queen.grm.N.bin]
#
# Analysis finished at 15:27:17 CET on Fri Jan 09 2026
# Overall computational time: 30.44 sec.

# %% [markdown]
# ###  Heritability

# %% [markdown]
# Create input for GREML analyses
# 1. phenotype file .phen
# 2. categorical variables .covar
# 3. continuous variables .qcovar

# %%
def write_pheno_file(h2_path, h2_name, gcta_df, phenotype):
    fn = '{}{}.phen'.format(h2_path, h2_name)
    gcta_df[['0', 'Colony', phenotype]].fillna('NA').to_csv(fn, header=None, sep='\t', index=False)

def write_covar_file(h2_path, h2_name, gcta_df, fixed_covar, tax_covar):

    temp_gcta_df = gcta_df.copy()
    
    # replace abundance values by presence-absence for prevalence associations
    temp_gcta_df[temp_gcta_df[tax_covar] >= lod] = int(1)
    temp_gcta_df[temp_gcta_df[tax_covar] < lod] = int(0)

    # # filter cases where too few 0 or 1 (case where bartonellacae had only 6 occurence , which was breaking the 
    # temp_gcta_df[tax_covar] = temp_gcta_df[tax_covar].loc[:, temp_gcta_df[tax_covar].apply(lambda col: col.value_counts().min() >= 10)]

    # drop columns with no variation in relative abundance (the break the h2 calculation)
    cols_to_remove = np.array(tax_covar)[np.array(temp_gcta_df[tax_covar].nunique() == 1)]
    temp_gcta_df = temp_gcta_df.drop(cols_to_remove, axis=1)
    
    fn = '{}{}.covar'.format(h2_path, h2_name)
    temp_gcta_df[['0', 'Colony'] + fixed_covar + [x for x in tax_covar if x not in cols_to_remove]].to_csv(fn, header=None, sep='\t', index=False)

def write_qcovar_file(h2_path, h2_name, gcta_df, fixed_qcovar, tax_qcovar):
    fn = '{}{}.qcovar'.format(h2_path, h2_name)
    gcta_df[['0', 'Colony'] + fixed_qcovar + tax_qcovar].to_csv(fn, header=None, sep='\t', index=False)

# %% [markdown]
# Combine metadata and symbiosphere data

# %%
pheno_df = pd.read_csv(metadata_fn)
abund_df = pd.read_csv('{}2026_Core_Family_LRA.csv'.format(tlf_path))
pca_df = pd.read_csv('{}2026_PCA_Core_Family_LRA.csv'.format(tlf_path)) # calculated in R

gcta_df = pheno_df.merge(abund_df, on='Colony').merge(pca_df.rename(columns={'Unnamed: 0': 'Colony'}), on='Colony')
gcta_df.insert(0, '0', [0] * len(gcta_df))

# reorder pheno df according to fam_df (order disrupted due to per-population genotype inference)
fam_df = pd.read_csv('{}hom_pop.fam'.format(plink_path), header=None, sep='\s') 
gcta_df = gcta_df.set_index("Colony").loc[fam_df[1].to_list()].reset_index()

# check consistent colony order between pheno df and plink
bs_ids = gcta_df['Colony'].to_list()
assert fam_df[1].to_list() == bs_ids, 'messed up colony order'

gcta_df
# Out:
# /tmp/ipykernel_4164612/4289707249.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   fam_df = pd.read_csv('{}hom_pop.fam'.format(plink_path), header=None, sep='\s')
#          Colony  0        date Genetic group  percent_Ligustica_Carnica  \
# 0     BS16_0060  0  06/07/2016     Caucasica                   0.118259
# 1     BS16_0061  0  06/07/2016     Caucasica                   0.109495
# 2     BS16_0162  0  31/08/2016     Caucasica                   0.047143
# 3     BS16_0163  0  31/08/2016     Caucasica                   0.015421
# 4     BS16_0164  0  31/08/2016     Caucasica                   0.005619
# ...         ... ..         ...           ...                        ...
# 1437  BS17_0506  0  01/08/2017        hybrid                   0.418368
# 1438  BS17_0511  0  01/08/2017        hybrid                   0.044593
# 1439  BS17_0512  0  01/08/2017        hybrid                   0.113869
# 1440  BS17_0513  0  01/08/2017        hybrid                   0.554205
# 1441  BS17_0517  0  01/08/2017        hybrid                   0.378583
#
#       percent_Mellifera  percent_Caucasica  bee_weigth  nbr_pho_varroa  \
# 0          1.369552e-04           0.881604        51.0             0.0
# 1          9.200239e-05           0.890413        52.0             1.0
# 2          1.376441e-05           0.952843        63.0            28.0
# 3          1.019360e-05           0.984569        52.0             2.0
# 4          4.687815e-08           0.994381        60.0             9.0
# ...                 ...                ...         ...             ...
# 1437       5.687723e-01           0.012860        47.5             1.0
# 1438       7.929777e-01           0.162429        41.0             0.0
# 1439       5.741510e-01           0.311980        39.2             0.0
# 1440       4.213804e-01           0.024415        43.0             0.0
# 1441       2.230246e-01           0.398393        56.0             5.0
#
#       nbr_pho_varroa_100bee  ...      PC70      PC71      PC72      PC73  \
# 0                       0.0  ...  0.353307  0.218941 -0.019820 -0.051705
# 1                       0.0  ...  0.308874 -0.266851  0.006458 -0.021666
# 2                       6.0  ... -0.092797  0.287065  0.073256  0.134700
# 3                       1.0  ...  0.051031 -0.045063  0.141150  0.054595
# 4                       2.0  ...  0.017741  0.296410  0.176600  0.126641
# ...                     ...  ...       ...       ...       ...       ...
# 1437                    0.0  ...  0.033991  0.033797 -0.001298 -0.176467
# 1438                    0.0  ... -0.221090 -0.188510  0.132250 -0.224776
# 1439                    0.0  ...  0.283573  0.104478  0.316437 -0.034634
# 1440                    0.0  ... -0.010661  0.340458  0.215753 -0.032503
# 1441                    1.0  ... -0.036247 -0.034704  0.183873 -0.216279
#
#           PC74      PC75      PC76      PC77      PC78      PC79
# 0     0.119433 -0.219744  0.101509 -0.086237 -0.010931  0.001891
# 1     0.015090  0.161015 -0.142289  0.046100 -0.027887 -0.027362
# 2     0.053442 -0.053158 -0.070834 -0.032747  0.046714  0.003519
# 3    -0.212183 -0.083976 -0.227077 -0.000919  0.060305  0.051721
# 4    -0.017109 -0.060639  0.051563 -0.080490 -0.074613  0.033566
# ...        ...       ...       ...       ...       ...       ...
# 1437 -0.097471 -0.044712  0.055281  0.167372  0.117209  0.010020
# 1438 -0.204183  0.147721  0.186332  0.121470  0.223099  0.018181
# 1439 -0.077343  0.272341  0.274449 -0.361698 -0.241724 -0.025222
# 1440  0.211349 -0.220104  0.328408 -0.342745 -0.102764 -0.003099
# 1441 -0.160219  0.060423  0.264667  0.039946  0.097669  0.030676
#
# [1442 rows x 203 columns]

# %%
phen2sig_fams_abun_str = {
    'log_v_meta':"Phasianidae,Morganellaceae,Cyprinidae,Bartonellaceae,Pseudomonadaceae,Lactobacillaceae,Bifidobacteriaceae,Bacillaceae,Enterobacteriaceae,Rosaceae",
    'log_v_pho':"Phasianidae,Morganellaceae,Trypanosomatidae,Nosematidae,Cyprinidae,Bifidobacteriaceae,Enterobacteriaceae,Rosaceae",
    'Recapping': "Morganellaceae,Bartonellaceae,Trypanosomatidae,Phasianidae,Nosematidae,Pseudomonadaceae,Fabaceae,Weeksellaceae,Cyprinidae,Inoviridae,Erwiniaceae,Rosaceae,Spiroplasmataceae",
    'DMR': "Danionidae,Hafniaceae"
}
phen2sig_fams_prev_str = {
    'log_v_meta':"Phasianidae,Cyprinidae,Bartonellaceae,Vespidae,Trypanosomatidae,Muridae,Weeksellaceae,Aeromonadaceae,Oscillospiraceae,Cannabaceae",
    'log_v_pho':"Phasianidae,Vespidae,Trypanosomatidae,Bartonellaceae,Cyprinidae,Actinomycetaceae,Cannabaceae,Muridae,Vibrionaceae,Danionidae,Oscillospiraceae",
    'Recapping': "Bartonellaceae,Trypanosomatidae,Phasianidae,Lachnospiraceae,Vespidae,Weeksellaceae,Cyprinidae,Plantaginaceae,Aeromonadaceae,Saccharomycodaceae,Poaceae,Flavobacteriaceae,Muridae,Pasteurellaceae,Vibrionaceae,Apiaceae,Cannabaceae,Bovidae",
    'DMR': "Tephritidae,Bartonellaceae"
}
phen2sig_fams_abun = {k: v.split(',') for k, v in phen2sig_fams_abun_str.items()}
phen2sig_fams_prev = {k: v.split(',') for k, v in phen2sig_fams_prev_str.items()}

# %%
max_pc = 6
sig_fams = True
default_covar = ['Apiary', 'Year']
default_qcovar = ['Day of Year']

cov_name2settings = {
    'default': (default_covar, [], default_qcovar, []),
    # 'gengroup'
}
if max_pc > 0:
    cov_name2settings |= {'Top_{}PCs'.format(i): (default_covar, [], default_qcovar, ['PC{}'.format(x) for x in range(1, i+1)]) for i in range(1, max_pc + 1)}
if sig_fams:
    cov_name2settings |= {
        'Sig_fams_all': (default_covar, [], default_qcovar, []),
        'Sig_fams_abun': (default_covar, [], default_qcovar, []),
        'Sig_fams_prev': (default_covar, [], default_qcovar, [])
    }

phenotypes = ['log_v_meta', 'log_v_pho', 'Recapping', 'DMR']
# phenotypes = ['v_meta']
# populations = ['all_pops', 'Mellifera', 'Ligustica_Carnica', 'hybrid']
# populations = ['all_pops']
populations = ['Mellifera', 'Ligustica_Carnica', 'hybrid']
mafs = ['001', '005']
# mafs = ['001']

# %%
overwrite = True

for pop, maf in product(populations, mafs):

    # get the GRM for the pop at the given MAF threshold (let's see if I need to recompute GRM when subsampling colonies)
    grm_path = '{}{}/GRM_maf{}/'.format(greml_path, pop, maf)
    grm_files = '{}{}'.format(grm_path, 'hom_pop' if pop == 'all_pops' else 'queen')
    
    # calculate heritability for each covariable setting
    for phen in phenotypes:

        if pop == 'all_pops':
            pop_gcta_df = gcta_df
        
        # subsample dataset to have the same number of colonies WITH phenotype per pop
        else: 
            pop_gcta_df = gcta_df.dropna(subset=[phen])[gcta_df['Genetic group'].isin({'Mellifera', 'Ligustica_Carnica', 'hybrid'})]
            min_col_nr = min(pop_gcta_df['Genetic group'].value_counts())
            pop_gcta_df = (
                pop_gcta_df
                .groupby("Genetic group", group_keys=False)
                .apply(lambda x: x.sample(n=min_col_nr, random_state=1234))
            )
            pop_gcta_df = pop_gcta_df[pop_gcta_df['Genetic group'] == pop]
            print(pop, phen, min_col_nr)
        
        for cov_name, (fixed_covar, tax_covar, fixed_qcovar, tax_qcovar) in cov_name2settings.items():
            
            h2_name = '{}_{}'.format(phen, cov_name)
            h2_path = '{}{}/maf{}_{}/'.format(greml_path, pop, maf, h2_name)
            print(h2_path)
            
            if not os.path.exists(h2_path):
                os.makedirs(h2_path)
            elif not overwrite:
                continue

            # if sig fams, phenotype-specific covariables
            if cov_name == 'Sig_fams_all':
                tax_covar = phen2sig_fams_prev[phen]
                tax_qcovar = phen2sig_fams_abun[phen]
            elif cov_name ==  'Sig_fams_abun':
                tax_qcovar = phen2sig_fams_abun[phen]
            elif cov_name ==  'Sig_fams_prev':
                tax_qcovar = phen2sig_fams_prev[phen]

            write_pheno_file(h2_path, h2_name, pop_gcta_df, phen)
            write_covar_file(h2_path, h2_name, pop_gcta_df, fixed_covar, tax_covar)
            write_qcovar_file(h2_path, h2_name, pop_gcta_df, fixed_qcovar, tax_qcovar)
        
            command = [gcta_path, '--reml', '--grm',  grm_files , '--pheno', '{}{}.phen'.format(h2_path, h2_name), '--covar', '{}{}.covar'.format(h2_path, h2_name), 
                   '--qcovar', '{}{}.qcovar'.format(h2_path, h2_name), '--out', '{}{}'.format(h2_path, h2_name)]
            result = subprocess.run(command, cwd=greml_path, capture_output=True, text=True)
            print(result.stderr)
            print(result.stdout)
# Out:
# /tmp/ipykernel_4164612/2946159890.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   pop_gcta_df
# Mellifera log_v_meta 372
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:29 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.qcovar].
# 1 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.covar].
#
# 1 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 66 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.35992  1.2629
# logL: -294.398
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-287.90	1.37030	1.06484
# 2	-285.22	1.36049	0.96863
# 3	-284.21	1.34965	0.91457
# 4	-283.79	1.34093	0.88186
# 5	-283.60	1.32045	0.81653
# 6	-283.45	1.31875	0.82106
# 7	-283.45	1.31886	0.82099
# 8	-283.45	1.31886	0.82100
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 2.01510
# logL: -308.12867
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-291.32	1.93722
# 2	-290.77	1.88890
# 3	-290.53	1.79064
# 4	-290.34	1.79548
# 5	-290.34	1.79550
# 6	-290.34	1.79550
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.318857	0.466825
# V(e)	0.820995	0.296737
# Vp	2.139852	0.239251
# V(G)/Vp	0.616331	0.164790
#
# Sampling variance/covariance of the estimates of variance components:
# 2.179253e-01	-1.243687e-01
# -1.243687e-01	8.805301e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_default/log_v_meta_default.hsq].
#
# Analysis finished at 16:33:30 CET on Wed Mar 04 2026
# Overall computational time: 0.12 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:30 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.qcovar].
# 2 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.covar].
#
# 2 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 67 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.34872 1.24376
# logL: -293.145
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-285.55	1.37037	1.01691
# 2	-282.23	1.36066	0.91305
# 3	-281.02	1.34847	0.85633
# 4	-280.52	1.33839	0.82260
# 5	-280.31	1.31448	0.75598
# 6	-280.13	1.31200	0.76144
# 7	-280.13	1.31225	0.76129
# 8	-280.13	1.31224	0.76130
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.96744
# logL: -307.59668
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-288.79	1.88346
# 2	-288.13	1.83190
# 3	-287.84	1.72770
# 4	-287.61	1.73329
# 5	-287.61	1.73331
# 6	-287.61	1.73331
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.312243	0.449309
# V(e)	0.761297	0.283604
# Vp	2.073539	0.231756
# V(G)/Vp	0.632852	0.161787
#
# Sampling variance/covariance of the estimates of variance components:
# 2.018788e-01	-1.142996e-01
# -1.142996e-01	8.043122e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_1PCs/log_v_meta_Top_1PCs.hsq].
#
# Analysis finished at 16:33:30 CET on Wed Mar 04 2026
# Overall computational time: 0.10 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:30 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.qcovar].
# 3 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.covar].
#
# 3 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 68 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.34871 1.24575
# logL: -295.768
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-288.26	1.34935	1.03291
# 2	-284.99	1.33108	0.93433
# 3	-283.79	1.31468	0.88008
# 4	-283.29	1.30234	0.84764
# 5	-283.08	1.27431	0.78334
# 6	-282.91	1.27262	0.78830
# 7	-282.91	1.27282	0.78818
# 8	-282.91	1.27281	0.78819
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.96772
# logL: -309.92286
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-291.07	1.88202
# 2	-290.39	1.82953
# 3	-290.09	1.72357
# 4	-289.86	1.72935
# 5	-289.86	1.72937
# 6	-289.86	1.72937
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.272810	0.448798
# V(e)	0.788186	0.285175
# Vp	2.060996	0.230602
# V(G)/Vp	0.617570	0.164321
#
# Sampling variance/covariance of the estimates of variance components:
# 2.014200e-01	-1.147837e-01
# -1.147837e-01	8.132493e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_2PCs/log_v_meta_Top_2PCs.hsq].
#
# Analysis finished at 16:33:30 CET on Wed Mar 04 2026
# Overall computational time: 0.11 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:30 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.qcovar].
# 4 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.covar].
#
# 4 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 69 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.35014 1.24775
# logL: -298.415
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-291.02	1.35514	1.03259
# 2	-287.78	1.33879	0.93297
# 3	-286.59	1.32339	0.87818
# 4	-286.10	1.31161	0.84544
# 5	-285.89	1.28462	0.78056
# 6	-285.72	1.28279	0.78560
# 7	-285.72	1.28299	0.78548
# 8	-285.72	1.28298	0.78549
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.97490
# logL: -312.49236
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-293.89	1.88815
# 2	-293.20	1.83507
# 3	-292.90	1.72798
# 4	-292.66	1.73387
# 5	-292.66	1.73389
# 6	-292.66	1.73389
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.282980	0.451460
# V(e)	0.785490	0.286644
# Vp	2.068470	0.231908
# V(G)/Vp	0.620256	0.164439
#
# Sampling variance/covariance of the estimates of variance components:
# 2.038157e-01	-1.160995e-01
# -1.160995e-01	8.216461e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_3PCs/log_v_meta_Top_3PCs.hsq].
#
# Analysis finished at 16:33:31 CET on Wed Mar 04 2026
# Overall computational time: 0.12 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:31 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.qcovar].
# 5 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.covar].
#
# 5 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 70 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.34992 1.24996
# logL: -300.366
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-293.06	1.32823	1.05255
# 2	-289.87	1.30121	0.95956
# 3	-288.69	1.28065	0.90786
# 4	-288.21	1.26610	0.87673
# 5	-288.00	1.23411	0.81470
# 6	-287.83	1.23331	0.81910
# 7	-287.83	1.23343	0.81902
# 8	-287.83	1.23343	0.81903
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.97260
# logL: -313.98668
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-295.23	1.88385
# 2	-294.51	1.82969
# 3	-294.20	1.72062
# 4	-293.95	1.72673
# 5	-293.95	1.72675
# 6	-293.95	1.72675
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.233430	0.450917
# V(e)	0.819026	0.288692
# Vp	2.052456	0.230406
# V(G)/Vp	0.600953	0.167714
#
# Sampling variance/covariance of the estimates of variance components:
# 2.033264e-01	-1.167911e-01
# -1.167911e-01	8.334294e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_4PCs/log_v_meta_Top_4PCs.hsq].
#
# Analysis finished at 16:33:31 CET on Wed Mar 04 2026
# Overall computational time: 0.11 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:31 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.qcovar].
# 6 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.covar].
#
# 6 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 71 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.34998 1.25052
# logL: -302.361
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-295.07	1.32442	1.05452
# 2	-291.87	1.29586	0.96205
# 3	-290.69	1.27458	0.91056
# 4	-290.20	1.25966	0.87953
# 5	-289.99	1.22706	0.81763
# 6	-289.82	1.22647	0.82191
# 7	-289.82	1.22658	0.82185
# 8	-289.82	1.22657	0.82186
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.97417
# logL: -315.91578
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-297.18	1.88379
# 2	-296.43	1.82875
# 3	-296.11	1.71803
# 4	-295.86	1.72433
# 5	-295.86	1.72435
# 6	-295.86	1.72435
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.226572	0.452248
# V(e)	0.821856	0.289855
# Vp	2.048429	0.230603
# V(G)/Vp	0.598787	0.168822
#
# Sampling variance/covariance of the estimates of variance components:
# 2.045279e-01	-1.176831e-01
# -1.176831e-01	8.401596e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_5PCs/log_v_meta_Top_5PCs.hsq].
#
# Analysis finished at 16:33:31 CET on Wed Mar 04 2026
# Overall computational time: 0.12 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:31 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.qcovar].
# 7 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.covar].
#
# 7 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 72 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.34984 1.25268
# logL: -304.428
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-297.22	1.29828	1.07381
# 2	-294.06	1.25970	0.98759
# 3	-292.89	1.23368	0.93898
# 4	-292.41	1.21625	0.90943
# 5	-292.20	1.17916	0.85014
# 6	-292.03	1.17956	0.85379
# 7	-292.03	1.17960	0.85378
# 8	-292.03	1.17960	0.85378
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.97621
# logL: -317.78490
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-299.08	1.88424
# 2	-298.31	1.82834
# 3	-297.99	1.71602
# 4	-297.73	1.72250
# 5	-297.73	1.72252
# 6	-297.73	1.72252
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.179596	0.453157
# V(e)	0.853778	0.292705
# Vp	2.033374	0.229549
# V(G)/Vp	0.580118	0.172542
#
# Sampling variance/covariance of the estimates of variance components:
# 2.053510e-01	-1.191670e-01
# -1.191670e-01	8.567598e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Top_6PCs/log_v_meta_Top_6PCs.hsq].
#
# Analysis finished at 16:33:31 CET on Wed Mar 04 2026
# Overall computational time: 0.10 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:32 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.qcovar].
# 11 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.covar].
# 11 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.covar].
#
# 11 quantitative variable(s) included as covariate(s).
# 11 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 85 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.33094 1.22776
# logL: -299.162
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-290.19	1.21170	1.03551
# 2	-285.46	1.14460	0.94883
# 3	-283.83	1.10427	0.90098
# 4	-283.17	1.07886	0.87214
# 5	-282.90	1.02674	0.81454
# 6	-282.67	1.02889	0.81815
# 7	-282.67	1.02892	0.81816
# 8	-282.67	1.02892	0.81816
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.90187
# logL: -312.22391
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-289.33	1.77333
# 2	-287.86	1.69946
# 3	-287.26	1.65398
# 4	-287.01	1.56193
# 5	-286.80	1.56677
# 6	-286.80	1.56678
# 7	-286.80	1.56678
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	1.028918	0.427064
# V(e)	0.818155	0.279033
# Vp	1.847074	0.213582
# V(G)/Vp	0.557053	0.181915
#
# Sampling variance/covariance of the estimates of variance components:
# 1.823835e-01	-1.073130e-01
# -1.073130e-01	7.785965e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_all/log_v_meta_Sig_fams_all.hsq].
#
# Analysis finished at 16:33:32 CET on Wed Mar 04 2026
# Overall computational time: 0.10 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:33 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.qcovar].
# 11 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.covar].
#
# 11 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 76 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.3292 1.2341
# logL: -298.713
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	-290.07	1.08444	1.14524
# 2	-285.86	0.97859	1.09077
# 3	-284.37	0.92131	1.05706
# 4	-283.77	0.88718	1.03553
# 5	-283.51	0.81941	0.99103
# 6	-283.30	0.82382	0.99278
# 7	-283.30	0.82385	0.99277
# 8	-283.30	0.82385	0.99277
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.88844
# logL: -311.15067
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	-288.18	1.77844
# 2	-287.03	1.71361
# 3	-286.55	1.67316
# 4	-286.34	1.59062
# 5	-286.18	1.59450
# 6	-286.18	1.59450
# 7	-286.18	1.59450
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.823854	0.409651
# V(e)	0.992771	0.278824
# Vp	1.816626	0.202921
# V(G)/Vp	0.453508	0.188097
#
# Sampling variance/covariance of the estimates of variance components:
# 1.678136e-01	-1.021898e-01
# -1.021898e-01	7.774287e-02
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_abun/log_v_meta_Sig_fams_abun.hsq].
#
# Analysis finished at 16:33:33 CET on Wed Mar 04 2026
# Overall computational time: 0.11 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:33:33 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# 405 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# GRM for 405 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/GRM_maf001/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.phen].
# Non-missing phenotypes of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.qcovar].
# 11 quantitative covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.covar].
# 2 discrete covariate(s) of 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/Mellifera/maf001_log_v_meta_Sig_fams_prev/log_v_meta_Sig_fams_prev.covar].
#
# 11 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 372 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 372 observations, 76 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 1.32346 1.21424
# logL: -293.88
# Running AI-REML algorithm ...
# ...
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Top_6PCs/DMR_Top_6PCs.covar].
# 2 discrete covariate(s) of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Top_6PCs/DMR_Top_6PCs.covar].
#
# 7 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 336 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 336 observations, 85 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.0193287 0.0203477
# logL: 223.551
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	224.72	0.01406	0.02416
# 2	225.59	0.01071	0.02676
# 3	226.00	0.00440	0.03201
# 4	226.31	0.00545	0.03152
# 5	226.32	0.00551	0.03150
# 6	226.32	0.00550	0.03150
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.03574
# logL: 225.75674
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	225.96	0.03556
# 2	225.97	0.03519
# 3	225.97	0.03519
# 4	225.97	0.03519
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.005503	0.008167
# V(e)	0.031497	0.005914
# Vp	0.037000	0.004428
# V(G)/Vp	0.148741	0.208463
#
# Sampling variance/covariance of the estimates of variance components:
# 6.669263e-05	-4.103297e-05
# -4.103297e-05	3.497665e-05
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Top_6PCs/DMR_Top_6PCs.hsq].
#
# Analysis finished at 16:34:51 CET on Wed Mar 04 2026
# Overall computational time: 0.08 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:34:51 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.phen].
# Non-missing phenotypes of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.qcovar].
# 3 quantitative covariate(s) of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.covar].
# 4 discrete covariate(s) of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.covar].
#
# 3 quantitative variable(s) included as covariate(s).
# 4 discrete variable(s) included as covariate(s).
# 336 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 336 observations, 83 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.0192987 0.0201471
# logL: 241.167
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	242.10	0.01544	0.02312
# 2	242.66	0.00676	0.03000
# 3	243.22	0.00687	0.03021
# 4	243.22	0.00688	0.03021
# 5	243.22	0.00688	0.03021
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.03542
# logL: 242.54896
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	242.84	0.03521
# 2	242.85	0.03478
# 3	242.86	0.03479
# 4	242.86	0.03479
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.006882	0.009267
# V(e)	0.030209	0.006441
# Vp	0.037091	0.004731
# V(G)/Vp	0.185547	0.232318
#
# Sampling variance/covariance of the estimates of variance components:
# 8.586825e-05	-5.248767e-05
# -5.248767e-05	4.148766e-05
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_all/DMR_Sig_fams_all.hsq].
#
# Analysis finished at 16:34:51 CET on Wed Mar 04 2026
# Overall computational time: 0.08 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:34:52 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.phen].
# Non-missing phenotypes of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.qcovar].
# 3 quantitative covariate(s) of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.covar].
# 2 discrete covariate(s) of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.covar].
#
# 3 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 336 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 336 observations, 81 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.0193405 0.0203198
# logL: 243.262
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	244.40	0.01465	0.02380
# 2	245.15	0.01145	0.02628
# 3	245.53	0.00496	0.03158
# 4	245.86	0.00546	0.03145
# 5	245.86	0.00551	0.03142
# 6	245.86	0.00551	0.03141
# 7	245.86	0.00551	0.03141
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.03564
# logL: 245.34839
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	245.58	0.03546
# 2	245.58	0.03509
# 3	245.59	0.03509
# 4	245.59	0.03509
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.005513	0.008489
# V(e)	0.031413	0.006081
# Vp	0.036926	0.004484
# V(G)/Vp	0.149307	0.217098
#
# Sampling variance/covariance of the estimates of variance components:
# 7.205774e-05	-4.446680e-05
# -4.446680e-05	3.697873e-05
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_abun/DMR_Sig_fams_abun.hsq].
#
# Analysis finished at 16:34:52 CET on Wed Mar 04 2026
# Overall computational time: 0.08 sec.
#
# /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/
#
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:34:52 CET on Wed Mar 04 2026.
# Hostname: node01
#
# Accepted options:
# --reml
# --grm /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen
# --pheno /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.phen
# --covar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.covar
# --qcovar /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.qcovar
# --out /cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# 372 IDs are read from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.id].
# Reading the GRM from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# GRM for 372 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/GRM_maf005/queen.grm.bin].
# Reading phenotypes from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.phen].
# Non-missing phenotypes of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.phen].
# Reading quantitative covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.qcovar].
# 3 quantitative covariate(s) of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.qcovar].
# Reading discrete covariate(s) from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.covar].
# 2 discrete covariate(s) of 336 individuals are included from [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.covar].
#
# 3 quantitative variable(s) included as covariate(s).
# 2 discrete variable(s) included as covariate(s).
# 336 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 336 observations, 81 fixed effect(s), and 2 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values:  0.019177 0.0200683
# logL: 246.021
# Running AI-REML algorithm ...
# Iter.	logL	V(G)	V(e)
# 1	246.83	0.01360	0.02390
# 2	247.64	0.00195	0.03232
# 3	248.33	0.00345	0.03178
# 4	248.38	0.00391	0.03150
# 5	248.38	0.00395	0.03147
# 6	248.38	0.00396	0.03147
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.03491
# logL: 247.68161
# Running AI-REML algorithm ...
# Iter.	logL	V(e)
# 1	248.15	0.03466
# 2	248.17	0.03412
# 3	248.18	0.03413
# 4	248.18	0.03413
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G)	0.003957	0.007381
# V(e)	0.031472	0.005512
# Vp	0.035428	0.004086
# V(G)/Vp	0.111678	0.199838
#
# Sampling variance/covariance of the estimates of variance components:
# 5.447209e-05	-3.408050e-05
# -3.408050e-05	3.038151e-05
#
# Summary result of REML analysis has been saved in the file [/cluster/raid/home/f80878961/beestrong/04_heritability_calculation/hom_pop/hybrid/maf005_DMR_Sig_fams_prev/DMR_Sig_fams_prev.hsq].
#
# Analysis finished at 16:34:52 CET on Wed Mar 04 2026
# Overall computational time: 0.08 sec.

# %% [markdown]
# ### plot by phenotype

# %%
maf = '001'
maf = '005'

# pop = 'Mellifera'
# pop = 'Ligustica_Carnica'
# pop = 'hybrid'
pop = 'all_pops'

phenotypes = ['log_v_meta', 'log_v_pho', 'Recapping', 'DMR']

# settings = ['default', 'VAF', 'top5VAF', '1PC', '2PC', '3PC', '4PC', '5PC', '10PC', '15PC', 'PC5', 'PC145']
# settings = ['default', '4PC']
cov_names = list(cov_name2settings)

pheno2h2_list = defaultdict(list)
pheno2se_list = defaultdict(list)
pheno2pv_list = defaultdict(list)

for phen in phenotypes:
    for cov_name in cov_names:

        h2_name = '{}_{}'.format(phen, cov_name)
        h2_path = '{}{}/maf{}_{}/'.format(greml_path, pop, maf, h2_name)
        
        hsq_fn = '{}{}.hsq'.format(h2_path, h2_name)
        if not os.path.exists(hsq_fn): 
            h2 = np.nan
            se = np.nan
            pv = np.nan
        else:
            h2 = pd.read_table(hsq_fn).iloc[3, 1]
            se = pd.read_table(hsq_fn).iloc[3, 2]
            pv = pd.read_table(hsq_fn).iloc[8, 1]
            
        pheno2h2_list[phen].append(h2)
        pheno2se_list[phen].append(se)
        pheno2pv_list[phen].append(pv)

# %%
h2_df = pd.DataFrame(pheno2h2_list)
h2_df.insert(0, 'Covariables', cov_names)
HTML(h2_df.round(3).to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Covariables</th>
#       <th>log_v_meta</th>
#       <th>log_v_pho</th>
#       <th>Recapping</th>
#       <th>DMR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.299</td>
#       <td>0.401</td>
#       <td>0.576</td>
#       <td>0.014</td>
#     </tr>
#     <tr>
#       <td>Top_1PCs</td>
#       <td>0.301</td>
#       <td>0.419</td>
#       <td>0.583</td>
#       <td>0.015</td>
#     </tr>
#     <tr>
#       <td>Top_2PCs</td>
#       <td>0.305</td>
#       <td>0.425</td>
#       <td>0.598</td>
#       <td>0.013</td>
#     </tr>
#     <tr>
#       <td>Top_3PCs</td>
#       <td>0.303</td>
#       <td>0.421</td>
#       <td>0.592</td>
#       <td>0.014</td>
#     </tr>
#     <tr>
#       <td>Top_4PCs</td>
#       <td>0.303</td>
#       <td>0.423</td>
#       <td>0.595</td>
#       <td>0.014</td>
#     </tr>
#     <tr>
#       <td>Top_5PCs</td>
#       <td>0.292</td>
#       <td>0.404</td>
#       <td>0.597</td>
#       <td>0.019</td>
#     </tr>
#     <tr>
#       <td>Top_6PCs</td>
#       <td>0.298</td>
#       <td>0.409</td>
#       <td>0.605</td>
#       <td>0.018</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_all</td>
#       <td>0.294</td>
#       <td>0.417</td>
#       <td>0.654</td>
#       <td>0.018</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_abun</td>
#       <td>0.291</td>
#       <td>0.414</td>
#       <td>0.593</td>
#       <td>0.017</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_prev</td>
#       <td>0.320</td>
#       <td>0.460</td>
#       <td>0.666</td>
#       <td>0.016</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(5, 5))
mat = h2_df.rename(columns=phen2name).set_index('Covariables')
sns.heatmap(
    mat,
    annot=mat,
    cmap="cubehelix",
    ax=ax
)
plt.title('H2 maf{}'.format(maf))
plt.show()

# %%
se_df = pd.DataFrame(pheno2se_list)
se_df.insert(0, 'Covariables', cov_names)
HTML(se_df.round(3).to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Covariables</th>
#       <th>log_v_meta</th>
#       <th>log_v_pho</th>
#       <th>Recapping</th>
#       <th>DMR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.090</td>
#       <td>0.093</td>
#       <td>0.070</td>
#       <td>0.041</td>
#     </tr>
#     <tr>
#       <td>Top_1PCs</td>
#       <td>0.090</td>
#       <td>0.093</td>
#       <td>0.067</td>
#       <td>0.042</td>
#     </tr>
#     <tr>
#       <td>Top_2PCs</td>
#       <td>0.090</td>
#       <td>0.092</td>
#       <td>0.067</td>
#       <td>0.041</td>
#     </tr>
#     <tr>
#       <td>Top_3PCs</td>
#       <td>0.090</td>
#       <td>0.092</td>
#       <td>0.067</td>
#       <td>0.042</td>
#     </tr>
#     <tr>
#       <td>Top_4PCs</td>
#       <td>0.090</td>
#       <td>0.093</td>
#       <td>0.067</td>
#       <td>0.042</td>
#     </tr>
#     <tr>
#       <td>Top_5PCs</td>
#       <td>0.092</td>
#       <td>0.093</td>
#       <td>0.068</td>
#       <td>0.044</td>
#     </tr>
#     <tr>
#       <td>Top_6PCs</td>
#       <td>0.092</td>
#       <td>0.093</td>
#       <td>0.068</td>
#       <td>0.044</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_all</td>
#       <td>0.098</td>
#       <td>0.094</td>
#       <td>0.081</td>
#       <td>0.044</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_abun</td>
#       <td>0.096</td>
#       <td>0.093</td>
#       <td>0.077</td>
#       <td>0.044</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_prev</td>
#       <td>0.095</td>
#       <td>0.092</td>
#       <td>0.079</td>
#       <td>0.042</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(5, 5))
mat = se_df.rename(columns=phen2name).set_index('Covariables')
sns.heatmap(
    mat,
    annot=mat,
    cmap="cubehelix",
    ax=ax
)
plt.title('SE maf{}'.format(maf))
plt.show()

# %%
pv_df = pd.DataFrame(pheno2pv_list)
pv_df.insert(0, 'Covariables', cov_names)
HTML(pv_df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Covariables</th>
#       <th>log_v_meta</th>
#       <th>log_v_pho</th>
#       <th>Recapping</th>
#       <th>DMR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.000003</td>
#       <td>3.039900e-06</td>
#       <td>2.919900e-14</td>
#       <td>0.35711</td>
#     </tr>
#     <tr>
#       <td>Top_1PCs</td>
#       <td>0.000001</td>
#       <td>7.167600e-07</td>
#       <td>4.996000e-16</td>
#       <td>0.35156</td>
#     </tr>
#     <tr>
#       <td>Top_2PCs</td>
#       <td>0.000001</td>
#       <td>4.648000e-07</td>
#       <td>2.220400e-16</td>
#       <td>0.37024</td>
#     </tr>
#     <tr>
#       <td>Top_3PCs</td>
#       <td>0.000001</td>
#       <td>5.240000e-07</td>
#       <td>2.220400e-16</td>
#       <td>0.35584</td>
#     </tr>
#     <tr>
#       <td>Top_4PCs</td>
#       <td>0.000002</td>
#       <td>7.176300e-07</td>
#       <td>2.775600e-16</td>
#       <td>0.36167</td>
#     </tr>
#     <tr>
#       <td>Top_5PCs</td>
#       <td>0.000003</td>
#       <td>1.217400e-06</td>
#       <td>5.551100e-16</td>
#       <td>0.31103</td>
#     </tr>
#     <tr>
#       <td>Top_6PCs</td>
#       <td>0.000003</td>
#       <td>1.044800e-06</td>
#       <td>3.885800e-16</td>
#       <td>0.31594</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_all</td>
#       <td>0.000175</td>
#       <td>3.139700e-06</td>
#       <td>8.079100e-13</td>
#       <td>0.32410</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_abun</td>
#       <td>0.000044</td>
#       <td>5.505600e-06</td>
#       <td>2.977100e-13</td>
#       <td>0.33698</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_prev</td>
#       <td>0.000018</td>
#       <td>1.958100e-07</td>
#       <td>1.998400e-14</td>
#       <td>0.33050</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### pop break down

# %%
list(cov_name2settings)
# Out:
# ['default',
#  'Top_1PCs',
#  'Top_2PCs',
#  'Top_3PCs',
#  'Top_4PCs',
#  'Top_5PCs',
#  'Top_6PCs',
#  'Sig_fams_all',
#  'Sig_fams_abun',
#  'Sig_fams_prev']

# %%
maf = '001'
maf = '005'

# pop = 'Mellifera'
# pop = 'Ligustica_Carnica'
# pop = 'hybrid'
# pop = 'all_pops'

phen = 'log_v_meta'
#phen = 'log_v_pho'
#phen = 'Recapping'
# phen = 'DMR'

populations = ['Mellifera', 'Ligustica_Carnica', 'hybrid']

# settings = ['default', 'VAF', 'top5VAF', '1PC', '2PC', '3PC', '4PC', '5PC', '10PC', '15PC', 'PC5', 'PC145']
# settings = ['default', '4PC']
cov_names = list(cov_name2settings)

pop2h2_list = defaultdict(list)
pop2se_list = defaultdict(list)
pop2pv_list = defaultdict(list)

for pop in populations:
    for cov_name in cov_names:

        h2_name = '{}_{}'.format(phen, cov_name)
        h2_path = '{}{}/maf{}_{}/'.format(greml_path, pop, maf, h2_name)
        
        hsq_fn = '{}{}.hsq'.format(h2_path, h2_name)
        if not os.path.exists(hsq_fn): 
            h2 = np.nan
            se = np.nan
            pv = np.nan
        else:
            h2 = pd.read_table(hsq_fn).iloc[3, 1]
            se = pd.read_table(hsq_fn).iloc[3, 2]
            pv = pd.read_table(hsq_fn).iloc[8, 1]
            
        pop2h2_list[pop].append(h2)
        pop2se_list[pop].append(se)
        pop2pv_list[pop].append(pv)

# %%
h2_df = pd.DataFrame(pop2h2_list)
h2_df.insert(0, 'Covariables', cov_names)
HTML(h2_df.round(3).to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Covariables</th>
#       <th>Mellifera</th>
#       <th>Ligustica_Carnica</th>
#       <th>hybrid</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.671</td>
#       <td>0.377</td>
#       <td>0.706</td>
#     </tr>
#     <tr>
#       <td>Top_1PCs</td>
#       <td>0.667</td>
#       <td>0.376</td>
#       <td>0.712</td>
#     </tr>
#     <tr>
#       <td>Top_2PCs</td>
#       <td>0.654</td>
#       <td>0.378</td>
#       <td>0.729</td>
#     </tr>
#     <tr>
#       <td>Top_3PCs</td>
#       <td>0.658</td>
#       <td>0.373</td>
#       <td>0.762</td>
#     </tr>
#     <tr>
#       <td>Top_4PCs</td>
#       <td>0.635</td>
#       <td>0.388</td>
#       <td>0.748</td>
#     </tr>
#     <tr>
#       <td>Top_5PCs</td>
#       <td>0.629</td>
#       <td>0.348</td>
#       <td>0.731</td>
#     </tr>
#     <tr>
#       <td>Top_6PCs</td>
#       <td>0.619</td>
#       <td>0.353</td>
#       <td>0.659</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_all</td>
#       <td>0.490</td>
#       <td>0.506</td>
#       <td>0.517</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_abun</td>
#       <td>0.422</td>
#       <td>0.414</td>
#       <td>0.637</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_prev</td>
#       <td>0.563</td>
#       <td>0.462</td>
#       <td>0.705</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(5, 5))
mat = h2_df.set_index('Covariables')
sns.heatmap(
    mat,
    annot=mat,
    cmap="cubehelix",
    ax=ax
)
plt.title('{} maf{}'.format(phen2name.get(phen, phen), maf))
plt.show()

# %%
se_df = pd.DataFrame(pop2se_list)
se_df.insert(0, 'Covariables', cov_names)
HTML(se_df.round(3).to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Covariables</th>
#       <th>Mellifera</th>
#       <th>Ligustica_Carnica</th>
#       <th>hybrid</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.198</td>
#       <td>0.198</td>
#       <td>0.211</td>
#     </tr>
#     <tr>
#       <td>Top_1PCs</td>
#       <td>0.198</td>
#       <td>0.200</td>
#       <td>0.209</td>
#     </tr>
#     <tr>
#       <td>Top_2PCs</td>
#       <td>0.215</td>
#       <td>0.200</td>
#       <td>0.209</td>
#     </tr>
#     <tr>
#       <td>Top_3PCs</td>
#       <td>0.216</td>
#       <td>0.201</td>
#       <td>0.209</td>
#     </tr>
#     <tr>
#       <td>Top_4PCs</td>
#       <td>0.217</td>
#       <td>0.201</td>
#       <td>0.210</td>
#     </tr>
#     <tr>
#       <td>Top_5PCs</td>
#       <td>0.203</td>
#       <td>0.201</td>
#       <td>0.212</td>
#     </tr>
#     <tr>
#       <td>Top_6PCs</td>
#       <td>0.229</td>
#       <td>0.201</td>
#       <td>0.213</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_all</td>
#       <td>0.175</td>
#       <td>0.199</td>
#       <td>0.234</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_abun</td>
#       <td>0.163</td>
#       <td>0.198</td>
#       <td>0.221</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_prev</td>
#       <td>0.213</td>
#       <td>0.198</td>
#       <td>0.208</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(5, 5))
mat = se_df.set_index('Covariables')
sns.heatmap(
    mat,
    annot=mat,
    cmap="cubehelix",
    ax=ax
)
plt.title('{} maf{}'.format(phen2name.get(phen, phen), maf))
plt.show()

# %%
pv_df = pd.DataFrame(pop2pv_list)
pv_df.insert(0, 'Covariables', cov_names)
HTML(pv_df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Covariables</th>
#       <th>Mellifera</th>
#       <th>Ligustica_Carnica</th>
#       <th>hybrid</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td>0.000104</td>
#       <td>0.039644</td>
#       <td>0.004863</td>
#     </tr>
#     <tr>
#       <td>Top_1PCs</td>
#       <td>0.000055</td>
#       <td>0.041636</td>
#       <td>0.004469</td>
#     </tr>
#     <tr>
#       <td>Top_2PCs</td>
#       <td>0.000097</td>
#       <td>0.041393</td>
#       <td>0.004218</td>
#     </tr>
#     <tr>
#       <td>Top_3PCs</td>
#       <td>0.000097</td>
#       <td>0.042977</td>
#       <td>0.002727</td>
#     </tr>
#     <tr>
#       <td>Top_4PCs</td>
#       <td>0.000233</td>
#       <td>0.036600</td>
#       <td>0.002853</td>
#     </tr>
#     <tr>
#       <td>Top_5PCs</td>
#       <td>0.000255</td>
#       <td>0.054805</td>
#       <td>0.004756</td>
#     </tr>
#     <tr>
#       <td>Top_6PCs</td>
#       <td>0.000368</td>
#       <td>0.051586</td>
#       <td>0.010093</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_all</td>
#       <td>0.002020</td>
#       <td>0.033588</td>
#       <td>0.030189</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_abun</td>
#       <td>0.008232</td>
#       <td>0.067167</td>
#       <td>0.024631</td>
#     </tr>
#     <tr>
#       <td>Sig_fams_prev</td>
#       <td>0.000970</td>
#       <td>0.016901</td>
#       <td>0.005418</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Old

# %% [markdown]
# ### .bim_like

# %% [markdown]
# I need to create bim-like files but be careful they are overwritten with make-bed command
#
# 1. Chromosome code
# 2. Variant ID
# 3. Position in centimorgans (safe to use dummy value of '0')
# 4. Base-pair coordinate (1-based; limited to 231-2)
# 5. ALT ('A1' in PLINK 1.x) allele code
# 6. REF ('A2' in PLINK 1.x) allele code

# %%
# %%time
with open('{}count_mat.pkl'.format(allele_count_path), 'rb') as inf:
    count_mat = pkl.load(inf)
print(count_mat.nbytes/1000000000)
# Out:
# 81.028587136
# CPU times: user 0 ns, sys: 1min 33s, total: 1min 33s
# Wall time: 1min 52s

# %%
f_snp_nr = 6764372
snp_nr = 7023976
assert snp_nr == count_mat.shape[0]

# %%
# %%time
# load original SNP ids
chr_ids = [''] * snp_nr
snp_pos = [''] * snp_nr
with open('{}data/gwas/BS17_0071.count'.format(working_path), 'r') as inf:
    print(inf.readline())
    i = 0
    for l in tqdm(inf):
        ch = l.split()[0]
        pos = l.split()[1]
        chr_ids[i] = ch
        snp_pos[i] = pos
        i += 1
# Out:
# CHROM POS REF ALT BS17-0071
# 7023976it [00:05, 1403874.48it/s]
# CPU times: user 4.31 s, sys: 685 ms, total: 5 s
# Wall time: 5.08 s

# %%
# %%time
# load filtered SNPs
f_chr_ids = [''] * f_snp_nr
f_snp_pos = [''] * f_snp_nr
with open('{}filtered_snps.txt'.format(allele_count_path), 'r') as inf:
    inf.readline()
    i = 0
    for l in tqdm(inf):
        ch = l.split()[0]
        pos = l.split()[1]
        f_chr_ids[i] = ch
        f_snp_pos[i] = pos
        i += 1
assert f_snp_nr == i
# Out:
# 6764372it [00:04, 1543827.37it/s]
# CPU times: user 3.7 s, sys: 676 ms, total: 4.37 s
# Wall time: 4.45 s

# %%
plink_path = '{}data/queen_genotypes/hom_pop/'.format(working_path)
bim = pd.read_csv('{}{}.bim'.format(plink_path, 'queen'), sep='\t', header=None)

# %%
# good
bim[3].to_list() == [int(x) for x in f_snp_pos]
# Out:
# True

# %%
# get back mask by comparing original snps and filtered snps. TO DO: if rerun filtering, include this part directly
snp_ids = ['{}_{}'.format(x, snp_pos[i]) for i, x in enumerate(chr_ids)]
f_snp_ids = ['{}_{}'.format(x, f_snp_pos[i]) for i, x in enumerate(f_chr_ids)]

assert len(snp_ids) == len(set(snp_ids))
assert len(f_snp_ids) == len(set(f_snp_ids))

snp_mask = ~np.isin(np.array(snp_ids), np.array(f_snp_ids))

assert np.sum(~snp_mask) == f_snp_nr

# %%
# find reference and alternative allele per SNP (REF: the one with the most counts. not sure if correct but probably REF and ALT are interchangeable) 
jj2allele = np.array(['A', 'T', 'C', 'G'])
ref_alt = np.full((snp_nr, 2), '.')
for i in tqdm(np.argwhere(~snp_mask).flatten()):
    ref_alt[i] = jj2allele[np.argsort(np.sum(count_mat[i, :, :], axis=0))[::-1][:2]]
# Out:
# 100%|██████████| 6764372/6764372 [03:30<00:00, 32146.91it/s]

# %%
bim_like = pd.DataFrame({
    'CHR': f_chr_ids,
    'SNP_ID': f_snp_ids,
    'GEN_DIST': ['0'] * f_snp_nr,
    'BP_POS': f_snp_pos,
    'ALT': ref_alt[~snp_mask][:, 1],
    'REF': ref_alt[~snp_mask][:, 0]
})

# %%
# recode snp id
chr2int = dict(zip(list(dict.fromkeys(bim_like['CHR'])), range(1, 1 + len(set(bim_like['CHR'])))))
bim_like['CHR'] = bim_like['CHR'].replace(chr2int)

def recode_SNP_ids(old_id):
    chrom, pos = old_id.split('.1_')
    return '{}:{}'.format(chr2int['{}.1'.format(chrom)], pos)

bim_like['SNP_ID'] = bim_like['SNP_ID'].map(recode_SNP_ids)
# Out:
# /tmp/ipykernel_3354437/2140746017.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bim_like['CHR'] = bim_like['CHR'].replace(chr2int)

# %%
bim_like
# Out:
#          CHR      SNP_ID GEN_DIST   BP_POS ALT REF
# 0          1      1:5671        0     5671   G   T
# 1          1      1:5698        0     5698   C   T
# 2          1      1:6621        0     6621   G   A
# 3          1      1:6717        0     6717   T   C
# 4          1      1:6823        0     6823   C   G
# ...      ...         ...      ...      ...  ..  ..
# 6764367   16  16:7225908        0  7225908   C   T
# 6764368   16  16:7225911        0  7225911   T   C
# 6764369   16  16:7226186        0  7226186   A   G
# 6764370   16  16:7226346        0  7226346   A   G
# 6764371   16  16:7227034        0  7227034   A   G
#
# [6764372 rows x 6 columns]

# %%
# good
bim[1].to_list() == bim_like['SNP_ID'].to_list()
# Out:
# True

# %%
# %%time
bim_like.to_csv('{}queen.bim_like'.format(hom_pop_path), header=False, index=False, sep='\t')
# Out:
# CPU times: user 6.47 s, sys: 509 ms, total: 6.98 s
# Wall time: 7.11 s

# %%
hom_pop_path
# Out:
# '/cluster/raid/home/f80878961/beestrong/data/queen_genotypes/hom_pop/'
